# %%
using Random
using LinearAlgebra
using Statistics
using StatsBase
using Plots
using Base.Threads
using Flux
using Base.Iterators: product
using Flux: Optimise
using Flux: ADAM, params, update!
using Serialization

# %%
include("permanents.jl")

#n_sessions = 2000  # Number of new sessions per iteration
#learning_rate = 0.001  # Learning rate, increase this to converge faster
percentile = 90  # Top 100-x percentile the agent will learn from
super_percentile = 90  # Top 100-x percentile of that survives to the next generation
# Out:
# 90

# %% [markdown]
# # Helper functions

# %%
function board_to_string(board::Vector{Int64}, n)
    # board is currently a Vector
    board = reshape(convert(Vector{Int}, board), (n,n))
    
    output = "["
    for i in 1:n-1
        output = output * string(board[:,i]) * '\n' * ' '
    end
    output = output * string(board[:,n]) * "]"

    return output
end
# Out:
# board_to_string (generic function with 1 method)

# %%
function new_point_allowed(one_indices, new_point_index, n)
    row = ceil(Int, new_point_index / n)
    col = new_point_index % n
    if col == 0; col = n end # julia is 1-indexed, so x*n mod(n) must be n rather than 0

    point_allowed = true

    for i in 1:length(one_indices) 
        for j in i+1:length(one_indices)
            point_one_row = ceil(Int, one_indices[i] / n)
            point_two_row = ceil(Int, one_indices[j] / n)
            #if point_one_row == 0; point_one_row end
            #if point_two_row == 0; point_two_row end

            point_one_col = one_indices[i] % n
            point_two_col = one_indices[j] % n
            if point_one_col == 0; point_one_col = n end
            if point_two_col == 0; point_two_col = n end

            if (  (row == point_one_row)
                | (row == point_two_row)
                | (point_one_row == point_two_row)
                | (col == point_one_col)
                | (col == point_two_col)
                | (point_one_col == point_two_col))
                continue
            end
            
            # ensure point_one_col < point_two_col
            if (point_two_col < point_one_col)
                point_one_row, point_two_row = point_two_row, point_one_row
                point_one_col, point_two_col = point_two_col, point_one_col
            end

            # new point as 1 in a valid 312-pattern
            if ((point_two_row < point_one_row < row) & (point_one_col < col < point_two_col))
                point_allowed = false
                break
            end

            # new point as 2 in a valid 312-pattern
            if ((point_two_row < row < point_one_row) & (col < point_one_col))
                point_allowed = false
                break
            end

            # new point as 3 in a valid 312-pattern
            if ((row < point_one_row < point_two_row) & (point_two_col < col))
                point_allowed = false
                break
            end
        end

        if point_allowed == false
            break
        end
        
    end

    return point_allowed
end
# Out:
# new_point_allowed (generic function with 1 method)

# %% [markdown]
# # Add points

# %%
# helper function to add 3 of the 5 free points present in all 312-avoiding matrices
function add_free_points(input_state, n, step)
    action_taken = 0 #zeros(n^2)
    cur_state = copy(input_state)

    if step == 1
        action_index = 1
    elseif step == 2
        action_index = n^2 - n + 1
    else # step == 3
        action_index = n^2
    end

    cur_state[action_index] = 1
    action_taken = action_index

    return cur_state, action_taken
end
# Out:
# add_free_points (generic function with 1 method)

# %%
function add_corner(input_state, action_vec, n, row_boundary, col_boundary)
    point_added = false
    action_taken = 0 #zeros(n^2)
    action_row = 0
    action_col = 0
    cur_state = copy(input_state)

    terminal = false

    ###
    # 1-indexing will make complicated, can just shift to 0-index then add later?
    # probably not that bad to use 1-indexing
    while !point_added
        action_index = StatsBase.sample(collect(1:length(action_vec)), Weights(action_vec), 1)[1]
        action_row = ceil(Int, action_index / n)
        action_col = action_index % n
        if action_col == 0; action_col = n end
        
        if (  ((action_row == n-1) & (action_col != n)) # the only corner in row n-1 possible is at (n-1, n)
            | ((action_col == 2) & (action_row != 1)) # only possible corner in col 2 is in row 1
            | ((row_boundary == 1) & (action_row != 1)) # ensures that first corner is in row 1.
            )
            action_vec[action_index] = 0
            action_vec = action_vec ./ sum(action_vec)
        elseif ((row_boundary <= action_row < n) & (col_boundary <= action_col)) # no corners in row n
            cur_state[action_index] = 1
            #action_taken[action_index] = 1
            action_taken = action_index
            point_added = true
        else
            action_vec[action_index] = 0
            action_vec = action_vec ./ sum(action_vec)
        end
    end

    if action_col == n
        terminal = true
    end

    return cur_state, action_taken, terminal, action_row, action_col
end
# Out:
# add_corner (generic function with 1 method)

# %%
function add_point(input_state, action_vec, n)
    point_added = false
    action_taken = 0 #zeros(Int, 1)
    cur_state = copy(input_state)
    
    while !point_added
        action_index = StatsBase.sample(collect(1:length(action_vec)), Weights(action_vec), 1)[1]
        one_indices = findall(!iszero, input_state)
        action_allowed = new_point_allowed(one_indices, action_index, n)
        
        if (cur_state[action_index] == 0) & (action_allowed)
            cur_state[action_index] = 1
            action_taken = action_index
            point_added = true
        else
            action_vec[action_index] = 0
            action_vec = action_vec ./ sum(action_vec)
        end
    end

    return cur_state, action_taken
end
# Out:
# add_point (generic function with 1 method)

# %% [markdown]
# # Generate sessions and super/ elite sessions

# %%
function generate_session(agent, corner_agent, n_sessions, n)
    states = zeros(Int, n_sessions, 4*n - 4 + 1, n^2)
    actions = zeros(Int, n_sessions, 4*n - 4 + 1)
    scores = zeros(Int, n_sessions)
    cur_state = zeros(Int, n^2)

    step = 0

    for i in 1:n_sessions # [1, n_sessions] inclusive
        step = 0
        #println(" ")
        #println("Sessions: " * string(i))
        # add first 3 free points, i.e., (1,1), (n,1), (n,n)
        while step < 3
            step += 1
            cur_state .= states[i, step, :]
            next_state, action = add_free_points(cur_state, n, step)

            actions[i, step] = action
            states[i, step + 1, :] = next_state
        end

        # add corners
        corner_num = 0
        corner_list = Vector{Int}(undef, 0)

        row_boundary, col_boundary = 1, 2
        #row_one_set = false
        terminal = false
        while !terminal
            step += 1
            cur_state .= states[i, step, :]

            output = corner_agent(cur_state)

            next_state, action, terminal, row_added, col_added = add_corner(cur_state, output, n, row_boundary, col_boundary)
            
            corner_index = (row_added - 1) * n + col_added
            push!(corner_list, corner_index)
            
            corner_num += 1

            row_boundary = row_added + 1
            col_boundary = col_added + 1

            actions[i, step] = action
            states[i, step + 1, :] = next_state
        end

        sort!(corner_list)

        # add induced corners
        for index in corner_list
            step += 1
            cur_state .= states[i, step, :]

            corner_row = ceil(Int, index / n)
            corner_col = index % n
            if corner_col == 0; corner_col = n end
            # induced_corner = (i+1, j-1) -> (i+1)n + (j-1), where i=corner_row and j=corner_col
            # so, e.g., induced_corner_row = corner_row + 1, induced_corner_col = corner_col - 1
            induced_corner_row, induced_corner_col = corner_row + 1, corner_col - 1

            # in general (for julia), index = (row - 1)*n + col
            induced_corner_index = (induced_corner_row - 1)*n + (induced_corner_col)
            cur_state[induced_corner_index] = 1

            actions[i, step] = induced_corner_index
            states[i, step + 1, :] = cur_state
        end

        ## add zig-zag
        push!(corner_list, n^2) # n^2 is not a corner, but we append it to work with while-loop below
        cur_path_element = 2 # first element on the zig-zag path, besides upper-left corner
        target_corner_num = 1
        target_corner = corner_list[target_corner_num]

        # first row of zig-zag path
        while cur_path_element != target_corner
            step += 1
            cur_state .= states[i, step, :]
            cur_state[cur_path_element] = 1

            #println("Step: " * string(step))
            #println("Curr element: " * string(cur_path_element))

            actions[i, step] = cur_path_element
            states[i, step + 1, :] = cur_state

            cur_path_element += 1 # step element by column, fixing row
        end

        #println("Length: " * string(length(corner_list)))
        #println(corner_list)
        # remaining points on zig-zag path
        target_corner_num += 1
        while target_corner_num <= length(corner_list)
            target_corner = corner_list[target_corner_num]
            target_row = ceil(target_corner / n)
            # target_col not needed

            cur_row = ceil(cur_path_element / n)
            #cur_col = cur_path_element % n
            #if cur_col == 0; cur_col = n end
            #println("Target corner num: " * string(target_corner_num))
            #println("Target corner: " * string(target_corner))
            while (cur_path_element != target_corner) & (cur_path_element != n^2 - n) # prevents incorrect row OR column
                if cur_row != target_row # must move row
                    # add point
                    step += 1
                    cur_path_element += n # step element by one row, fixing column
                    cur_state .= states[i, step, :]
                    cur_state[cur_path_element] = 1

                    #println("Step: " * string(step))
                    #println("Curr element: " * string(cur_path_element))
        
                    actions[i, step] = cur_path_element
                    states[i, step + 1, :] = cur_state
        
                    cur_row += 1
                else # cur_col != target_col, i.e., correct row but must move column
                    cur_path_element += 1 # step element by one column, fixing row
                    if cur_path_element != target_corner # move column
                        # add point
                        step += 1
                        cur_state .= states[i, step, :]
                        cur_state[cur_path_element] = 1

                        #println("Step: " * string(step))
                        #println("Curr element: " * string(cur_path_element))

                        actions[i, step] = cur_path_element
                        states[i, step + 1, :] = cur_state

                        #cur_col += 1
                    end
                end
            end
            target_corner_num += 1
            #println("target num after: " * string(target))
            #println("step after loop:" * string(step))
        end

        # add remaining points
        while step < 4*n - 4 # there are 4*n - 4 steps total, starts at 0 and ends at 4*n - 4 - 1
            step += 1
            # current board
            cur_state .= states[i, step, :]

            output = agent(cur_state)

            next_state, action = add_point(cur_state, output, n)

            actions[i, step] = action
            states[i, step + 1, :] = next_state
        end

        final_state = states[i, step + 1, :]
        final_state_matrix = reshape(final_state, (n,n))
        scores[i] = glynn(final_state_matrix)
    end

    return states, actions, scores
end
# Out:
# generate_session (generic function with 1 method)

# %%
function select_super_sessions(states_batch, actions_batch, rewards_batch, super_percentile)
    counter = n_sessions * (100 - super_percentile) / 100
    reward_threshold = quantile(rewards_batch, super_percentile / 100)

    super_states = zeros(Int, 0, size(states_batch, 2), size(states_batch, 3))
    super_actions = Matrix{Int}(undef, 0, size(actions_batch, 2))
    super_rewards = Vector{Int}(undef, 0)
    
    for i in 1:size(states_batch, 1)
        if rewards_batch[i] >= reward_threshold - 0.000001 && counter > 0
            temp_state = reshape(states_batch[i, :, :], (1,size(states_batch[i, :, :])...))
            super_states = cat(super_states, temp_state; dims=1)

            temp_actions = reshape(actions_batch[i, :], (1,size(actions_batch[i, :])...))
            super_actions = cat(super_actions, temp_actions; dims=1)

            push!(super_rewards, rewards_batch[i])

            counter -= 1
        end
    end

    return super_states, super_actions, super_rewards
end
# Out:
# select_super_sessions (generic function with 1 method)

# %%
function select_elites(states_batch, actions_batch, rewards_batch, percentile)
    counter = n_sessions * (100 - percentile) / 100
    reward_threshold = quantile(rewards_batch, percentile / 100)

    elite_states = Matrix{Int}(undef, 0, size(states_batch, 3))
    elite_actions = Vector{Int}(undef, 0)
    
    for i in 1:size(states_batch, 1)
        if rewards_batch[i] >= reward_threshold - 0.000001 && counter > 0
            for item in eachrow(states_batch[i, :, :])
                temp_state = reshape(item, 1, size(states_batch, 3)) # size of board
                elite_states = vcat(elite_states, temp_state)
            end

            for item in actions_batch[i, :]
                push!(elite_actions, item)
            end

            counter -= 1
        end
    end

    return elite_states, elite_actions
end
# Out:
# select_elites (generic function with 1 method)

# %% [markdown]
# # Training function

# %%
function train(board_size, filename)
    n_sessions = 2000
    learning_rate = 0.001
    corner_learning_rate = 0.0001

    n = board_size
    input_space = n*n

    first_layer_neurons = 128
    second_layer_neurons = 64
    third_layers_neurons = 4

    # Define the neural network architecture (similar to PyTorch)
    net = Chain(
        Dense(n^2, first_layer_neurons, relu),
        Dense(first_layer_neurons, second_layer_neurons, relu),
        Dense(second_layer_neurons, third_layers_neurons, relu),
        Dense(third_layers_neurons, n^2, σ)
    )

    # Define the neural network architecture (similar to PyTorch)
    corner_net = Chain(
        Dense(n^2, first_layer_neurons, relu),
        Dense(first_layer_neurons, second_layer_neurons, relu),
        Dense(second_layer_neurons, third_layers_neurons, relu),
        Dense(third_layers_neurons, n^2, σ)
    )

    # Defining the loss function and optimizer (similar to PyTorch)
    criterion(y_pred, y_true) = Flux.binarycrossentropy(y_pred, y_true)
    optimizer = Optimise.ADAM(learning_rate)
    corner_optimizer = Optimise.ADAM(corner_learning_rate)

    # Global lists
    global super_states = Array{Int}(undef, 0, 4*n - 4 + 1, n^2)
    global super_actions = Array{Int}(undef, 0, 4*n - 4 + 1)
    global super_rewards = Int[]

    cur_best_reward = 0
    cur_best_board = []
    cur_best_game = []
    local best_states_set
    
    for i in 1:20000
        println("\n GENERATION $i")
        states_batch, actions_batch, rewards_batch = generate_session(net, corner_net, n_sessions, n)
        #println("new batch size: " * string(size(states_batch)))

        if i > 1
            states_batch = cat(states_batch, super_states; dims=1)
            actions_batch = cat(actions_batch, super_actions; dims=1)
            rewards_batch = cat(rewards_batch, super_rewards; dims=1)
            #println("super size: " * string(size(super_states)))
        end
        #println("batch size after cat: " * string(size(states_batch)))

        elite_states, elite_actions = select_elites(states_batch, actions_batch, rewards_batch, percentile)

        ###
        # sessions[1][i,:,:] are the states corresponding to the ith session
        # likewise for actions and rewards
        # the outer dimension is now the number of sessions
        # the next dimension indicates (1 = states, 2 = actions, 3 = rewards)
        # reverse sort the sessions (in the outer dimension) based on the rewards
        # sessions = select_super_sessions(states_batch, actions_batch, rewards_batch, super_percentile)
        ###
        super_states, super_actions, super_rewards = select_super_sessions(states_batch, actions_batch, rewards_batch, super_percentile)
        sessions = [super_states, super_actions, super_rewards]

        ### error: this is not updating super_states, below we concat with old super_states.. error below
        #println("new super size: " * string(size(super_states))) # this is not new, this is old
        #println(size(sessions[1]))
        super_sessions = [[sessions[1][i,:,:], sessions[2][i,:], sessions[3][i]] for i in 1:length(sessions[3])]
        #println(size(super_sessions))
        sort!(super_sessions, by = x -> x[3], rev=true)

        #### delete
        #if i == 2
        #    println(board_to_string(super_sessions[1][1][4*n - 4 + 1,:],n)) # 1st session, states of first session, last state
        #    println(super_sessions[1][3])
        #end

        # optimize
        # Backward pass (gradients calculation) and optimization (similar to PyTorch)
        net_outputs = zeros(Float32, size(elite_states, 1), 1)
        corner_net_outputs = zeros(Float32, size(elite_states, 1), 1)
        for i in 1:size(elite_states,1)
            net_outputs[i] = net(elite_states[i, :, :])[1]
            corner_net_outputs[i] = corner_net(elite_states[i, :, :])[1]
        end

        loss = criterion(net_outputs, elite_actions)
        grads = gradient(() -> loss, params(net))
        Optimise.update!(optimizer, params(net), grads)

        loss = criterion(corner_net_outputs, elite_actions)
        grads = gradient(() -> loss, params(corner_net))
        Optimise.update!(corner_optimizer, params(corner_net), grads)
        # retrieve the sorted states, actions, rewards
        # i corresponds to the ith session, 1 corresponds to the states of the ith session
        # this is initally size (4n-4+1, n^2) but needs to be (1, 4n-4+1, n^2)

        #####
        # TODO
        # currently just resetting super_states, need to stack them
        # possible error here, fix here or above.
        super_states = Array{Int}(undef, 0, 4*n - 4 + 1, n^2)
        super_actions = Array{Int}(undef, 0, 4*n - 4 + 1)
        for i in 1:length(super_sessions)
            # just use super_states_reshaped?
            super_states_reshaped = reshape(super_sessions[i][1], (1, size(super_sessions[i][1])...))
            super_states = cat(super_states, super_states_reshaped; dims=1)

            super_actions_reshaped = reshape(super_sessions[i][2], (1, size(super_sessions[i][2])...))
            super_actions = cat(super_actions, super_actions_reshaped; dims=1)
        end
        super_rewards = [super_sessions[i][3] for i in 1:length(super_sessions)]

        mean_best_reward = mean(super_rewards)

        println("\n$i. Best individuals: ", super_rewards)
        # Uncomment the line below to print out the mean best reward
        println("Mean best reward: $mean_best_reward")

        # Make a new folder if 'Data' folder does not exist
        if !isdir("Data_two_agent")
            mkdir("Data_two_agent")
        end

        max_index = argmax(super_rewards)
        #max_index = 1

        if super_rewards[max_index] > cur_best_reward
            cur_best_reward = super_rewards[max_index]
            cur_best_board = super_states[max_index, 4*n-4+1,:] # best board as vector
            cur_best_game = super_states[max_index,:,:]

            best_states_set = Set()
            push!(best_states_set, string(cur_best_board))
            
            # add to file
            open(joinpath("Data_two_agent", filename * "_best_board_timeline.txt"), "a") do f
                write(f, board_to_string(cur_best_board, n), '\n')
            end
            open(joinpath("Data_two_agent", filename * "_best_reward_timeline.txt"), "a") do f
                write(f, string(cur_best_reward), '\n')
            end
            if cur_best_reward == 424
                open(joinpath("Data_two_agent", filename * "_best_reward_timeline.txt"), "a") do f
                    write(f, "GENERATION $i", '\n')
                end
            end
        end
        
        if super_rewards[max_index] == cur_best_reward
            cur_best_board = super_states[max_index, 4*n-4+1,:] # best board as vector
            if !in(string(cur_best_board), best_states_set)
                push!(best_states_set, string(cur_best_board))

                # add to file
                open(joinpath("Data_two_agent", filename * "_best_board_timeline.txt"), "a") do f
                    write(f, board_to_string(cur_best_board, n), '\n')
                end
                open(joinpath("Data_two_agent", filename * "_best_reward_timeline.txt"), "a") do f
                    write(f, string(cur_best_reward), '\n')
                end
            end
    
        end
        
    end
        return net, corner_net, cur_best_game
end
# Out:
# train (generic function with 1 method)

# %% [markdown]
# # Training

# %%
#n_sessions = 200
n = 10
filename = "10x10"
best_net, best_corner_net, best_game = train(n, filename)
# Out:
#  GENERATION 1
#
# 1. Best individuals: [100, 96, 96, 66, 63, 60, 52, 52, 44, 40, 36, 36, 36, 36, 34, 32, 24, 24, 24, 20]
# Mean best reward: 48.55
#
#  GENERATION 2
#
# 2. Best individuals: [86, 70, 68, 63, 52, 50, 48, 48, 46, 44, 36, 36, 32, 28, 28, 24, 21, 20, 20, 20]
# Mean best reward: 42.0
#
#  GENERATION 3
#
# 3. Best individuals: [87, 80, 78, 74, 72, 72, 68, 66, 56, 56, 54, 54, 52, 40, 40, 40, 37, 36, 36, 36]
# Mean best reward: 56.7
#
#  GENERATION 4
#
# 4. Best individuals: [120, 106, 105, 95, 84, 81, 60, 52, 52, 52, 48, 48, 44, 40, 30, 28, 27, 24, 24, 24]
# Mean best reward: 57.2
#
#  GENERATION 5
#
# 5. Best individuals: [88, 80, 76, 64, 60, 48, 42, 40, 36, 36, 32, 30, 30, 28, 24, 24, 24, 24, 24, 24]
# Mean best reward: 41.7
#
#  GENERATION 6
#
# 6. Best individuals: [198, 94, 72, 60, 60, 51, 48, 44, 38, 36, 32, 30, 26, 24, 24, 24, 24, 24, 24, 24]
# Mean best reward: 47.85
#
#  GENERATION 7
#
# 7. Best individuals: [89, 80, 72, 58, 56, 52, 51, 50, 48, 44, 40, 36, 34, 32, 28, 26, 24, 24, 24, 24]
# Mean best reward: 44.6
#
#  GENERATION 8
#
# 8. Best individuals: [152, 128, 90, 80, 78, 64, 55, 44, 42, 42, 40, 35, 32, 32, 32, 30, 24, 24, 24, 24]
# Mean best reward: 53.6
#
#  GENERATION 9
#
# 9. Best individuals: [164, 144, 125, 122, 88, 83, 80, 66, 62, 56, 54, 44, 42, 40, 40, 33, 32, 32, 24, 24]
# Mean best reward: 67.75
#
#  GENERATION 10
#
# 10. Best individuals: [224, 217, 152, 104, 90, 66, 60, 58, 54, 52, 48, 36, 36, 32, 30, 30, 26, 24, 24, 24]
# Mean best reward: 69.35
#
#  GENERATION 11
#
# 11. Best individuals: [155, 126, 116, 72, 72, 70, 60, 60, 48, 48, 46, 44, 38, 32, 30, 26, 24, 24, 24, 24]
# Mean best reward: 56.95
#
#  GENERATION 12
#
# 12. Best individuals: [158, 98, 81, 79, 67, 56, 48, 46, 42, 42, 36, 35, 34, 32, 28, 26, 24, 24, 24, 24]
# Mean best reward: 50.2
#
#  GENERATION 13
#
# 13. Best individuals: [150, 132, 120, 92, 89, 85, 78, 72, 62, 60, 60, 56, 56, 50, 48, 42, 40, 40, 40, 32]
# Mean best reward: 70.2
#
#  GENERATION 14
#
# 14. Best individuals: [191, 138, 99, 80, 72, 68, 54, 48, 46, 32, 32, 30, 30, 28, 27, 24, 24, 20, 20, 18]
# Mean best reward: 54.05
#
#  GENERATION 15
#
# 15. Best individuals: [120, 102, 84, 72, 68, 68, 60, 48, 48, 48, 48, 45, 44, 42, 40, 40, 36, 27, 26, 24]
# Mean best reward: 54.5
#
#  GENERATION 16
#
# 16. Best individuals: [226, 116, 106, 84, 80, 70, 60, 54, 54, 45, 40, 32, 32, 28, 24, 24, 22, 22, 20, 20]
# Mean best reward: 57.95
#
#  GENERATION 17
#
# 17. Best individuals: [147, 144, 110, 96, 84, 84, 76, 72, 60, 54, 51, 46, 38, 36, 32, 32, 30, 26, 24, 24]
# Mean best reward: 63.3
#
#  GENERATION 18
#
# 18. Best individuals: [126, 112, 96, 90, 68, 68, 60, 56, 50, 49, 48, 36, 36, 32, 32, 29, 24, 24, 24, 22]
# Mean best reward: 54.1
#
#  GENERATION 19
#
# 19. Best individuals: [164, 112, 96, 76, 72, 60, 57, 57, 56, 48, 44, 40, 38, 36, 32, 27, 24, 24, 24, 22]
# Mean best reward: 55.45
#
#  GENERATION 20
#
# 20. Best individuals: [150, 120, 96, 78, 76, 72, 60, 60, 60, 57, 54, 52, 42, 28, 27, 24, 24, 20, 18, 18]
# Mean best reward: 56.8
#
#  GENERATION 21
#
# 21. Best individuals: [112, 96, 80, 72, 68, 54, 52, 48, 45, 42, 36, 36, 36, 32, 30, 24, 24, 24, 24, 24]
# Mean best reward: 47.95
#
#  GENERATION 22
#
# 22. Best individuals: [100, 88, 75, 74, 72, 64, 60, 56, 48, 48, 40, 36, 36, 36, 36, 30, 26, 24, 24, 20]
# Mean best reward: 49.65
#
#  GENERATION 23
#
# 23. Best individuals: [112, 70, 56, 42, 42, 32, 32, 32, 32, 28, 28, 28, 28, 24, 24, 24, 24, 24, 24, 16]
# Mean best reward: 36.1
#
#  GENERATION 24
#
# 24. Best individuals: [125, 98, 72, 70, 70, 66, 59, 58, 56, 50, 50, 48, 44, 42, 42, 32, 30, 24, 24, 24]
# Mean best reward: 54.2
#
#  GENERATION 25
#
# 25. Best individuals: [154, 126, 116, 108, 102, 99, 58, 55, 42, 38, 32, 32, 32, 32, 30, 24, 24, 24, 24, 20]
# Mean best reward: 58.6
#
#  GENERATION 26
#
# 26. Best individuals: [62, 61, 60, 52, 48, 48, 48, 40, 40, 36, 36, 34, 32, 32, 30, 25, 24, 24, 24, 24]
# Mean best reward: 39.0
#
#  GENERATION 27
#
# 27. Best individuals: [167, 143, 94, 91, 88, 84, 64, 64, 63, 60, 56, 50, 45, 39, 36, 36, 32, 32, 20, 20]
# Mean best reward: 64.2
#
#  GENERATION 28
#
# 28. Best individuals: [126, 107, 92, 84, 84, 78, 70, 58, 42, 41, 39, 36, 36, 30, 30, 28, 27, 24, 24, 22]
# Mean best reward: 53.9
#
#  GENERATION 29
#
# 29. Best individuals: [86, 78, 70, 70, 68, 63, 52, 48, 44, 42, 40, 39, 36, 32, 32, 28, 24, 24, 24, 24]
# Mean best reward: 46.2
#
#  GENERATION 30
#
# 30. Best individuals: [140, 119, 114, 92, 78, 74, 54, 44, 42, 42, 40, 38, 32, 28, 24, 24, 24, 24, 24, 24]
# Mean best reward: 54.05
#
#  GENERATION 31
#
# 31. Best individuals: [183, 150, 88, 80, 80, 66, 60, 56, 48, 48, 44, 36, 36, 30, 28, 24, 24, 24, 24, 22]
# Mean best reward: 57.55
#
#  GENERATION 32
#
# 32. Best individuals: [154, 142, 96, 88, 80, 72, 60, 60, 42, 42, 36, 36, 32, 32, 32, 30, 24, 24, 24, 24]
# Mean best reward: 56.5
#
#  GENERATION 33
#
# 33. Best individuals: [72, 68, 60, 60, 55, 54, 52, 40, 36, 33, 32, 30, 28, 24, 24, 24, 24, 20, 20, 20]
# Mean best reward: 38.8
#
#  GENERATION 34
#
# 34. Best individuals: [212, 144, 90, 90, 78, 60, 60, 60, 56, 56, 54, 52, 36, 33, 28, 28, 24, 24, 24, 24]
# Mean best reward: 61.65
#
#  GENERATION 35
#
# 35. Best individuals: [126, 88, 88, 77, 64, 56, 54, 48, 40, 40, 40, 40, 36, 32, 27, 24, 24, 24, 20, 20]
# Mean best reward: 48.4
#
#  GENERATION 36
#
# 36. Best individuals: [108, 104, 88, 76, 75, 75, 68, 54, 51, 48, 44, 42, 40, 33, 32, 32, 30, 28, 24, 20]
# Mean best reward: 53.6
#
#  GENERATION 37
#
# 37. Best individuals: [144, 105, 82, 72, 72, 57, 56, 48, 48, 47, 40, 40, 32, 32, 28, 24, 20, 20, 18, 18]
# Mean best reward: 50.15
#
#  GENERATION 38
#
# 38. Best individuals: [232, 85, 84, 72, 70, 58, 58, 48, 42, 36, 32, 30, 28, 20, 20, 20, 18, 16, 16, 16]
# Mean best reward: 50.05
#
#  GENERATION 39
#
# 39. Best individuals: [126, 100, 99, 96, 77, 67, 60, 48, 44, 40, 38, 36, 36, 33, 33, 32, 28, 28, 24, 24]
# Mean best reward: 53.45
#
#  GENERATION 40
#
# 40. Best individuals: [128, 126, 110, 90, 90, 66, 56, 50, 44, 39, 36, 32, 27, 24, 24, 20, 20, 18, 18, 18]
# Mean best reward: 51.8
#
#  GENERATION 41
#
# 41. Best individuals: [184, 117, 114, 94, 84, 77, 64, 54, 54, 45, 44, 32, 32, 32, 32, 26, 24, 22, 22, 21]
# Mean best reward: 58.7
#
#  GENERATION 42
#
# 42. Best individuals: [204, 174, 146, 105, 100, 96, 94, 48, 36, 32, 32, 30, 30, 24, 22, 20, 18, 16, 16, 16]
# Mean best reward: 62.95
#
#  GENERATION 43
#
# 43. Best individuals: [124, 84, 76, 66, 63, 46, 42, 40, 36, 36, 35, 32, 30, 28, 24, 24, 24, 21, 20, 18]
# Mean best reward: 43.45
#
#  GENERATION 44
#
# 44. Best individuals: [206, 80, 76, 72, 62, 60, 60, 56, 56, 54, 48, 40, 40, 36, 32, 27, 24, 24, 20, 16]
# Mean best reward: 54.45
#
#  GENERATION 45
#
# 45. Best individuals: [123, 88, 80, 72, 66, 61, 56, 54, 54, 48, 48, 42, 40, 33, 30, 24, 24, 20, 18, 16]
# Mean best reward: 49.85
#
#  GENERATION 46
#
# 46. Best individuals: [190, 136, 126, 92, 75, 72, 60, 48, 48, 42, 36, 36, 35, 32, 32, 32, 28, 25, 24, 24]
# Mean best reward: 59.65
#
#  GENERATION 47
#
# 47. Best individuals: [176, 108, 107, 86, 72, 63, 48, 45, 44, 40, 38, 36, 36, 32, 32, 32, 30, 28, 24, 24]
# Mean best reward: 55.05
#
#  GENERATION 48
#
# 48. Best individuals: [179, 105, 96, 84, 72, 64, 64, 56, 54, 42, 40, 40, 36, 36, 30, 30, 30, 28, 24, 24]
# Mean best reward: 56.7
#
#  GENERATION 49
#
# 49. Best individuals: [154, 104, 84, 72, 70, 64, 50, 48, 40, 40, 40, 36, 32, 30, 30, 24, 24, 24, 24, 24]
# Mean best reward: 50.7
#
#  GENERATION 50
#
# 50. Best individuals: [108, 96, 90, 66, 48, 48, 43, 36, 34, 33, 24, 24, 24, 24, 24, 24, 24, 18, 18, 18]
# Mean best reward: 41.2
#
#  GENERATION 51
#
# 51. Best individuals: [132, 109, 102, 90, 64, 54, 48, 48, 48, 48, 48, 44, 44, 42, 36, 34, 32, 32, 28, 28]
# Mean best reward: 55.55
#
#  GENERATION 52
#
# 52. Best individuals: [132, 72, 72, 56, 54, 50, 48, 48, 42, 36, 36, 36, 36, 33, 32, 32, 32, 28, 24, 24]
# Mean best reward: 46.15
#
#  GENERATION 53
#
# 53. Best individuals: [146, 105, 86, 54, 52, 48, 48, 44, 44, 36, 32, 30, 28, 24, 24, 24, 22, 20, 20, 16]
# Mean best reward: 45.15
#
#  GENERATION 54
#
# 54. Best individuals: [136, 102, 96, 92, 84, 68, 60, 56, 52, 48, 48, 42, 42, 39, 32, 28, 22, 20, 20, 20]
# Mean best reward: 55.35
#
#  GENERATION 55
#
# 55. Best individuals: [187, 112, 112, 106, 88, 84, 74, 56, 52, 52, 48, 48, 40, 33, 32, 32, 32, 28, 24, 24]
# Mean best reward: 63.2
#
#  GENERATION 56
#
# 56. Best individuals: [188, 120, 107, 102, 70, 60, 60, 55, 50, 43, 40, 32, 30, 24, 24, 24, 24, 24, 24, 24]
# Mean best reward: 56.25
#
#  GENERATION 57
#
# 57. Best individuals: [204, 168, 139, 107, 96, 92, 74, 64, 42, 40, 40, 38, 36, 36, 36, 36, 33, 32, 30, 28]
# Mean best reward: 68.55
#
#  GENERATION 58
#
# 58. Best individuals: [100, 72, 66, 60, 54, 48, 46, 44, 44, 42, 36, 36, 32, 32, 32, 32, 30, 30, 24, 20]
# Mean best reward: 44.0
#
#  GENERATION 59
#
# 59. Best individuals: [168, 105, 104, 78, 68, 63, 60, 56, 56, 48, 42, 36, 36, 34, 32, 27, 26, 24, 24, 24]
# Mean best reward: 55.55
#
#  GENERATION 60
#
# 60. Best individuals: [180, 117, 90, 88, 88, 69, 69, 48, 40, 40, 40, 40, 38, 36, 36, 30, 26, 24, 24, 24]
# Mean best reward: 57.35
#
#  GENERATION 61
#
# 61. Best individuals: [156, 150, 140, 114, 91, 90, 85, 72, 60, 48, 44, 35, 32, 30, 24, 24, 24, 24, 24, 24]
# Mean best reward: 64.55
#
#  GENERATION 62
#
# 62. Best individuals: [148, 118, 103, 98, 96, 96, 88, 70, 54, 54, 52, 48, 40, 36, 34, 28, 24, 24, 24, 24]
# Mean best reward: 62.95
#
#  GENERATION 63
#
# 63. Best individuals: [177, 148, 106, 60, 60, 44, 36, 36, 32, 32, 30, 26, 24, 24, 24, 24, 24, 24, 20, 20]
# Mean best reward: 48.55
#
#  GENERATION 64
#
# 64. Best individuals: [190, 98, 96, 70, 58, 56, 45, 44, 40, 40, 36, 32, 30, 28, 28, 26, 24, 24, 24, 24]
# Mean best reward: 50.65
#
#  GENERATION 65
#
# 65. Best individuals: [196, 160, 120, 70, 68, 52, 44, 36, 36, 36, 36, 36, 33, 32, 32, 30, 30, 24, 24, 24]
# Mean best reward: 55.95
#
#  GENERATION 66
#
# 66. Best individuals: [201, 88, 80, 77, 68, 48, 48, 48, 46, 44, 39, 36, 36, 32, 32, 32, 30, 24, 24, 20]
# Mean best reward: 52.65
#
#  GENERATION 67
#
# 67. Best individuals: [156, 133, 132, 124, 124, 79, 68, 66, 64, 60, 60, 60, 60, 60, 58, 56, 52, 48, 36, 35]
# Mean best reward: 76.55
#
#  GENERATION 68
#
# 68. Best individuals: [102, 99, 80, 68, 62, 51, 48, 46, 30, 28, 24, 24, 24, 24, 22, 21, 20, 20, 18, 18]
# Mean best reward: 41.45
#
#  GENERATION 69
#
# 69. Best individuals: [130, 124, 120, 108, 100, 90, 78, 77, 72, 70, 64, 54, 48, 44, 40, 36, 36, 32, 24, 20]
# Mean best reward: 68.35
#
#  GENERATION 70
#
# 70. Best individuals: [188, 140, 130, 116, 100, 96, 60, 52, 46, 42, 40, 36, 36, 32, 30, 30, 27, 24, 24, 24]
# Mean best reward: 63.65
#
#  GENERATION 71
#
# 71. Best individuals: [276, 199, 143, 136, 126, 88, 84, 72, 68, 58, 56, 46, 46, 39, 36, 36, 30, 28, 28, 26]
# Mean best reward: 81.05
#
#  GENERATION 72
#
# 72. Best individuals: [136, 94, 85, 82, 82, 80, 79, 47, 44, 40, 36, 36, 36, 32, 32, 32, 28, 27, 24, 24]
# Mean best reward: 53.8
#
#  GENERATION 73
#
# 73. Best individuals: [120, 110, 84, 78, 66, 64, 63, 60, 56, 52, 50, 45, 36, 32, 32, 28, 27, 24, 24, 24]
# Mean best reward: 53.75
#
#  GENERATION 74
#
# 74. Best individuals: [130, 118, 106, 94, 72, 70, 60, 60, 60, 52, 48, 48, 42, 42, 32, 32, 32, 24, 24, 24]
# Mean best reward: 58.5
#
#  GENERATION 75
#
# 75. Best individuals: [256, 130, 128, 82, 77, 60, 56, 52, 48, 44, 38, 33, 30, 28, 28, 24, 24, 24, 24, 24]
# Mean best reward: 60.5
#
#  GENERATION 76
#
# 76. Best individuals: [114, 110, 109, 70, 55, 48, 48, 42, 42, 40, 40, 36, 36, 32, 30, 30, 30, 24, 24, 24]
# Mean best reward: 49.2
#
#  GENERATION 77
#
# 77. Best individuals: [160, 126, 105, 99, 58, 52, 52, 48, 48, 48, 45, 44, 36, 36, 32, 32, 24, 24, 24, 24]
# Mean best reward: 55.85
#
#  GENERATION 78
#
# 78. Best individuals: [126, 116, 112, 92, 78, 64, 60, 60, 41, 40, 36, 36, 36, 36, 36, 30, 24, 20, 20, 20]
# Mean best reward: 54.15
#
#  GENERATION 79
#
# 79. Best individuals: [122, 87, 68, 64, 64, 60, 60, 56, 44, 40, 36, 32, 30, 26, 26, 24, 24, 22, 20, 20]
# Mean best reward: 46.25
#
#  GENERATION 80
#
# 80. Best individuals: [140, 132, 130, 112, 76, 72, 72, 64, 56, 54, 48, 42, 40, 36, 32, 32, 24, 24, 20, 20]
# Mean best reward: 61.3
#
#  GENERATION 81
#
# 81. Best individuals: [190, 126, 101, 98, 84, 80, 54, 48, 42, 40, 36, 36, 34, 32, 30, 28, 28, 27, 24, 20]
# Mean best reward: 57.9
#
#  GENERATION 82
#
# 82. Best individuals: [190, 168, 164, 134, 130, 84, 80, 65, 64, 52, 48, 40, 39, 34, 32, 30, 30, 26, 24, 24]
# Mean best reward: 72.9
#
#  GENERATION 83
#
# 83. Best individuals: [90, 84, 80, 72, 56, 37, 36, 32, 32, 30, 28, 28, 21, 21, 20, 20, 18, 16, 16, 16]
# Mean best reward: 37.65
#
#  GENERATION 84
#
# 84. Best individuals: [108, 104, 100, 60, 54, 48, 44, 44, 42, 36, 36, 30, 30, 30, 24, 24, 24, 24, 22, 20]
# Mean best reward: 45.2
#
#  GENERATION 85
#
# 85. Best individuals: [189, 142, 106, 92, 76, 76, 74, 72, 54, 51, 45, 44, 42, 30, 30, 27, 24, 24, 22, 20]
# Mean best reward: 62.0
#
#  GENERATION 86
#
# 86. Best individuals: [129, 112, 107, 80, 74, 66, 60, 56, 56, 56, 56, 48, 42, 42, 40, 39, 36, 36, 32, 28]
# Mean best reward: 59.75
#
#  GENERATION 87
#
# 87. Best individuals: [188, 126, 102, 100, 90, 84, 84, 70, 56, 56, 54, 48, 44, 39, 36, 32, 27, 24, 21, 20]
# Mean best reward: 65.05
#
#  GENERATION 88
#
# 88. Best individuals: [155, 152, 108, 83, 75, 60, 57, 56, 50, 46, 42, 39, 32, 32, 28, 28, 28, 24, 24, 21]
# Mean best reward: 57.0
#
#  GENERATION 89
#
# 89. Best individuals: [227, 120, 109, 106, 103, 103, 102, 72, 62, 42, 42, 40, 28, 28, 24, 24, 21, 20, 18, 18]
# Mean best reward: 65.45
#
#  GENERATION 90
#
# 90. Best individuals: [76, 76, 66, 66, 65, 48, 48, 46, 42, 36, 28, 28, 28, 26, 26, 24, 24, 24, 24, 24]
# Mean best reward: 41.25
#
#  GENERATION 91
#
# 91. Best individuals: [164, 138, 120, 103, 103, 70, 66, 66, 63, 60, 54, 48, 48, 44, 42, 40, 36, 24, 24, 24]
# Mean best reward: 66.85
#
#  GENERATION 92
#
# 92. Best individuals: [168, 138, 114, 100, 88, 84, 70, 49, 48, 46, 40, 40, 40, 38, 36, 29, 27, 24, 24, 24]
# Mean best reward: 61.35
#
#  GENERATION 93
#
# 93. Best individuals: [182, 114, 98, 84, 72, 54, 53, 52, 50, 40, 39, 34, 32, 32, 28, 28, 28, 24, 24, 24]
# Mean best reward: 54.6
#
#  GENERATION 94
#
# 94. Best individuals: [114, 98, 83, 79, 73, 72, 62, 60, 48, 42, 42, 34, 32, 32, 30, 28, 28, 24, 24, 24]
# Mean best reward: 51.45
#
#  GENERATION 95
#
# 95. Best individuals: [226, 206, 157, 121, 90, 88, 75, 64, 63, 60, 36, 36, 36, 36, 36, 36, 34, 32, 32, 32]
# Mean best reward: 74.8
#
#  GENERATION 96
#
# 96. Best individuals: [158, 140, 140, 131, 113, 107, 72, 63, 36, 36, 36, 32, 32, 32, 28, 28, 24, 22, 20, 20]
# Mean best reward: 63.5
#
#  GENERATION 97
#
# 97. Best individuals: [298, 104, 70, 56, 52, 48, 40, 40, 36, 32, 32, 28, 24, 24, 24, 24, 24, 24, 21, 20]
# Mean best reward: 51.05
#
#  GENERATION 98
#
# 98. Best individuals: [112, 82, 81, 78, 54, 48, 44, 40, 40, 40, 40, 36, 36, 36, 30, 26, 24, 24, 24, 24]
# Mean best reward: 45.95
#
#  GENERATION 99
#
# 99. Best individuals: [109, 84, 66, 58, 56, 54, 50, 48, 44, 40, 33, 32, 28, 26, 24, 24, 24, 24, 20, 20]
# Mean best reward: 43.2
#
#  GENERATION 100
#
# 100. Best individuals: [204, 134, 110, 80, 73, 68, 68, 60, 58, 52, 48, 42, 42, 36, 32, 28, 24, 24, 24, 24]
# Mean best reward: 61.55
#
#  GENERATION 101
#
# 101. Best individuals: [112, 84, 76, 72, 70, 48, 48, 45, 42, 40, 40, 40, 40, 39, 38, 32, 28, 24, 20, 20]
# Mean best reward: 47.9
#
#  GENERATION 102
#
# 102. Best individuals: [210, 168, 92, 64, 54, 48, 44, 40, 36, 36, 36, 36, 28, 27, 24, 24, 24, 24, 24, 18]
# Mean best reward: 52.85
#
#  GENERATION 103
#
# 103. Best individuals: [101, 75, 64, 54, 46, 45, 32, 32, 32, 32, 30, 28, 26, 26, 24, 21, 21, 18, 18, 18]
# Mean best reward: 37.15
#
#  GENERATION 104
#
# 104. Best individuals: [200, 144, 126, 88, 80, 76, 72, 66, 60, 58, 52, 48, 36, 36, 36, 36, 34, 32, 32, 24]
# Mean best reward: 66.8
#
#  GENERATION 105
#
# 105. Best individuals: [186, 172, 72, 70, 63, 54, 52, 48, 48, 42, 40, 40, 36, 36, 36, 33, 28, 28, 24, 24]
# Mean best reward: 56.6
#
#  GENERATION 106
#
# 106. Best individuals: [142, 142, 140, 96, 90, 88, 80, 76, 66, 62, 60, 48, 44, 40, 36, 36, 32, 30, 24, 24]
# Mean best reward: 67.8
#
#  GENERATION 107
#
# 107. Best individuals: [104, 92, 90, 76, 68, 60, 60, 56, 54, 52, 48, 48, 36, 32, 24, 24, 24, 24, 24, 24]
# Mean best reward: 51.0
#
#  GENERATION 108
#
# 108. Best individuals: [185, 114, 104, 98, 84, 80, 74, 72, 62, 56, 46, 40, 40, 36, 24, 24, 24, 24, 21, 20]
# Mean best reward: 61.4
#
#  GENERATION 109
#
# 109. Best individuals: [140, 84, 62, 58, 56, 56, 48, 48, 46, 44, 36, 36, 30, 27, 24, 24, 24, 24, 24, 24]
# Mean best reward: 45.75
#
#  GENERATION 110
#
# 110. Best individuals: [113, 103, 84, 76, 76, 74, 63, 60, 58, 58, 54, 54, 52, 44, 28, 27, 24, 24, 24, 24]
# Mean best reward: 56.0
#
#  GENERATION 111
#
# 111. Best individuals: [187, 112, 106, 100, 64, 64, 60, 60, 56, 50, 48, 42, 42, 36, 36, 32, 28, 24, 24, 24]
# Mean best reward: 59.75
#
#  GENERATION 112
#
# 112. Best individuals: [139, 108, 104, 96, 88, 80, 80, 78, 72, 56, 48, 42, 42, 36, 35, 32, 30, 24, 24, 24]
# Mean best reward: 61.9
#
#  GENERATION 113
#
# 113. Best individuals: [148, 114, 105, 103, 80, 72, 64, 58, 48, 48, 46, 40, 36, 34, 32, 32, 30, 28, 28, 24]
# Mean best reward: 58.5
#
#  GENERATION 114
#
# 114. Best individuals: [125, 124, 90, 77, 48, 40, 40, 40, 40, 30, 28, 28, 28, 28, 24, 24, 24, 24, 24, 20]
# Mean best reward: 45.3
#
#  GENERATION 115
#
# 115. Best individuals: [75, 72, 70, 56, 36, 34, 32, 32, 32, 30, 27, 24, 24, 24, 24, 24, 24, 24, 24, 18]
# Mean best reward: 35.3
#
#  GENERATION 116
#
# 116. Best individuals: [108, 72, 72, 66, 63, 61, 60, 60, 56, 48, 40, 40, 32, 30, 28, 28, 24, 22, 20, 18]
# Mean best reward: 47.4
#
#  GENERATION 117
#
# 117. Best individuals: [178, 150, 99, 85, 76, 72, 62, 60, 60, 60, 48, 48, 44, 40, 36, 30, 26, 24, 24, 24]
# Mean best reward: 62.3
#
#  GENERATION 118
#
# 118. Best individuals: [136, 105, 96, 72, 72, 68, 64, 64, 57, 48, 46, 45, 42, 40, 34, 32, 30, 24, 24, 24]
# Mean best reward: 56.15
#
#  GENERATION 119
#
# 119. Best individuals: [104, 70, 70, 60, 56, 50, 49, 48, 48, 40, 36, 36, 30, 28, 26, 24, 24, 24, 24, 24]
# Mean best reward: 43.55
#
#  GENERATION 120
#
# 120. Best individuals: [141, 120, 66, 66, 56, 48, 48, 45, 44, 38, 36, 32, 28, 28, 24, 24, 24, 24, 24, 24]
# Mean best reward: 47.0
#
#  GENERATION 121
#
# 121. Best individuals: [140, 94, 90, 82, 73, 68, 60, 60, 32, 28, 24, 24, 24, 21, 20, 18, 18, 18, 16, 16]
# Mean best reward: 46.3
#
#  GENERATION 122
#
# 122. Best individuals: [174, 146, 101, 100, 77, 76, 65, 48, 46, 42, 40, 40, 28, 26, 24, 24, 24, 24, 20, 20]
# Mean best reward: 57.25
#
#  GENERATION 123
#
# 123. Best individuals: [96, 70, 68, 66, 64, 45, 44, 40, 40, 38, 36, 30, 28, 24, 24, 24, 21, 20, 20, 20]
# Mean best reward: 40.9
#
#  GENERATION 124
#
# 124. Best individuals: [167, 90, 70, 68, 66, 56, 48, 44, 42, 40, 36, 36, 32, 28, 24, 24, 20, 20, 20, 20]
# Mean best reward: 47.55
#
#  GENERATION 125
#
# 125. Best individuals: [136, 96, 85, 82, 80, 74, 72, 60, 60, 60, 56, 50, 44, 34, 30, 30, 24, 24, 24, 24]
# Mean best reward: 57.25
#
#  GENERATION 126
#
# 126. Best individuals: [340, 225, 75, 74, 66, 56, 54, 48, 48, 37, 36, 32, 30, 30, 26, 24, 24, 24, 24, 24]
# Mean best reward: 64.85
#
#  GENERATION 127
#
# 127. Best individuals: [207, 133, 80, 64, 57, 56, 48, 36, 36, 36, 36, 34, 33, 32, 32, 26, 24, 22, 20, 20]
# Mean best reward: 51.6
#
#  GENERATION 128
#
# 128. Best individuals: [114, 90, 84, 72, 66, 51, 46, 42, 40, 40, 36, 30, 26, 26, 24, 24, 24, 24, 24, 20]
# Mean best reward: 45.15
#
#  GENERATION 129
#
# 129. Best individuals: [156, 108, 84, 64, 60, 52, 48, 44, 32, 32, 32, 28, 28, 26, 24, 24, 24, 21, 18, 18]
# Mean best reward: 46.15
#
#  GENERATION 130
#
# 130. Best individuals: [182, 96, 80, 60, 48, 48, 46, 42, 40, 40, 38, 36, 36, 36, 30, 28, 28, 24, 24, 24]
# Mean best reward: 49.3
#
#  GENERATION 131
#
# 131. Best individuals: [86, 80, 74, 56, 52, 52, 48, 48, 48, 40, 32, 32, 32, 32, 28, 27, 27, 24, 24, 20]
# Mean best reward: 43.1
#
#  GENERATION 132
#
# 132. Best individuals: [137, 118, 110, 98, 90, 89, 80, 64, 60, 60, 52, 48, 48, 40, 36, 30, 28, 28, 27, 27]
# Mean best reward: 63.5
#
#  GENERATION 133
#
# 133. Best individuals: [156, 132, 94, 86, 84, 72, 68, 66, 58, 48, 39, 34, 33, 32, 32, 32, 28, 26, 24, 24]
# Mean best reward: 58.4
#
#  GENERATION 134
#
# 134. Best individuals: [136, 104, 94, 76, 74, 65, 64, 60, 56, 52, 48, 48, 48, 48, 32, 32, 24, 24, 24, 24]
# Mean best reward: 56.65
#
#  GENERATION 135
#
# 135. Best individuals: [136, 133, 124, 122, 88, 80, 80, 78, 52, 48, 48, 44, 42, 42, 34, 32, 30, 28, 28, 24]
# Mean best reward: 64.65
#
#  GENERATION 136
#
# 136. Best individuals: [258, 154, 128, 104, 102, 96, 83, 48, 44, 40, 40, 40, 39, 38, 36, 30, 24, 24, 24, 23]
# Mean best reward: 68.75
#
#  GENERATION 137
#
# 137. Best individuals: [132, 120, 108, 93, 88, 82, 65, 64, 64, 60, 52, 49, 40, 36, 36, 34, 30, 30, 28, 24]
# Mean best reward: 61.75
#
#  GENERATION 138
#
# 138. Best individuals: [125, 104, 102, 96, 55, 50, 48, 46, 40, 39, 38, 36, 30, 30, 28, 28, 28, 24, 21, 20]
# Mean best reward: 49.4
#
#  GENERATION 139
#
# 139. Best individuals: [116, 96, 90, 80, 60, 54, 54, 52, 50, 44, 40, 40, 40, 36, 32, 30, 24, 24, 24, 24]
# Mean best reward: 50.5
#
#  GENERATION 140
#
# 140. Best individuals: [128, 80, 74, 70, 60, 60, 56, 48, 42, 38, 36, 30, 30, 28, 28, 24, 24, 24, 22, 21]
# Mean best reward: 46.15
#
#  GENERATION 141
#
# 141. Best individuals: [152, 120, 102, 96, 80, 74, 65, 60, 52, 44, 40, 32, 30, 30, 28, 24, 24, 24, 18, 18]
# Mean best reward: 55.65
#
#  GENERATION 142
#
# 142. Best individuals: [188, 84, 82, 68, 48, 47, 44, 42, 42, 40, 39, 36, 32, 24, 24, 24, 24, 24, 20, 20]
# Mean best reward: 47.6
#
#  GENERATION 143
#
# 143. Best individuals: [230, 140, 96, 90, 82, 60, 56, 56, 51, 44, 40, 40, 40, 32, 28, 27, 24, 24, 24, 24]
# Mean best reward: 60.4
#
#  GENERATION 144
#
# 144. Best individuals: [154, 120, 96, 96, 92, 90, 81, 80, 60, 52, 44, 39, 36, 36, 32, 32, 30, 28, 24, 24]
# Mean best reward: 62.3
#
#  GENERATION 145
#
# 145. Best individuals: [122, 112, 81, 76, 56, 51, 48, 44, 44, 40, 36, 36, 30, 28, 27, 24, 24, 24, 24, 24]
# Mean best reward: 47.55
#
#  GENERATION 146
#
# 146. Best individuals: [126, 91, 87, 76, 74, 62, 62, 57, 54, 50, 46, 44, 36, 32, 22, 20, 18, 18, 16, 16]
# Mean best reward: 50.35
#
#  GENERATION 147
#
# 147. Best individuals: [176, 112, 60, 60, 60, 52, 44, 42, 36, 36, 32, 32, 32, 30, 28, 28, 24, 24, 18, 18]
# Mean best reward: 47.2
#
#  GENERATION 148
#
# 148. Best individuals: [96, 90, 84, 80, 74, 68, 60, 54, 52, 50, 48, 48, 34, 30, 28, 24, 24, 24, 24, 22]
# Mean best reward: 50.7
#
#  GENERATION 149
#
# 149. Best individuals: [202, 180, 128, 108, 60, 56, 48, 44, 44, 36, 36, 36, 36, 28, 26, 24, 20, 20, 20, 20]
# Mean best reward: 58.6
#
#  GENERATION 150
#
# 150. Best individuals: [114, 80, 76, 75, 64, 56, 48, 44, 42, 40, 40, 30, 28, 28, 28, 24, 24, 24, 24, 20]
# Mean best reward: 45.45
#
#  GENERATION 151
#
# 151. Best individuals: [155, 106, 72, 72, 64, 58, 56, 39, 36, 36, 30, 30, 28, 28, 27, 24, 24, 24, 24, 24]
# Mean best reward: 47.85
#
#  GENERATION 152
#
# 152. Best individuals: [103, 97, 87, 68, 64, 54, 48, 48, 42, 40, 40, 36, 36, 32, 32, 30, 27, 26, 24, 24]
# Mean best reward: 47.9
#
#  GENERATION 153
#
# 153. Best individuals: [212, 126, 123, 56, 55, 54, 54, 48, 48, 44, 42, 36, 32, 32, 32, 32, 30, 30, 24, 24]
# Mean best reward: 56.7
#
#  GENERATION 154
#
# 154. Best individuals: [68, 64, 60, 59, 58, 49, 48, 48, 44, 33, 32, 28, 28, 27, 26, 24, 24, 24, 24, 20]
# Mean best reward: 39.4
#
#  GENERATION 155
#
# 155. Best individuals: [130, 96, 84, 80, 72, 60, 60, 48, 48, 48, 42, 36, 36, 28, 28, 24, 22, 22, 18, 18]
# Mean best reward: 50.0
#
#  GENERATION 156
#
# 156. Best individuals: [104, 90, 86, 84, 78, 72, 66, 60, 60, 57, 48, 40, 36, 36, 28, 26, 24, 24, 20, 18]
# Mean best reward: 52.85
#
#  GENERATION 157
#
# 157. Best individuals: [180, 166, 154, 119, 81, 80, 72, 63, 52, 52, 48, 48, 44, 44, 44, 30, 30, 24, 24, 24]
# Mean best reward: 68.95
#
#  GENERATION 158
#
# 158. Best individuals: [140, 133, 132, 118, 95, 64, 60, 56, 54, 54, 48, 48, 48, 48, 48, 36, 36, 36, 24, 24]
# Mean best reward: 65.1
#
#  GENERATION 159
#
# 159. Best individuals: [201, 148, 96, 92, 88, 75, 48, 48, 36, 36, 36, 32, 30, 24, 24, 24, 22, 20, 20, 20]
# Mean best reward: 56.0
#
#  GENERATION 160
#
# 160. Best individuals: [244, 152, 127, 102, 80, 66, 64, 62, 60, 56, 42, 32, 32, 32, 32, 32, 30, 28, 24, 24]
# Mean best reward: 66.05
#
#  GENERATION 161
#
# 161. Best individuals: [170, 126, 105, 82, 80, 46, 38, 36, 36, 33, 32, 32, 32, 24, 24, 24, 24, 24, 20, 20]
# Mean best reward: 50.4
#
#  GENERATION 162
#
# 162. Best individuals: [140, 93, 80, 64, 64, 60, 60, 58, 55, 52, 48, 46, 44, 44, 44, 30, 24, 24, 24, 24]
# Mean best reward: 53.9
#
#  GENERATION 163
#
# 163. Best individuals: [148, 116, 93, 80, 78, 60, 60, 56, 56, 48, 45, 38, 30, 27, 26, 24, 24, 24, 20, 20]
# Mean best reward: 53.65
#
#  GENERATION 164
#
# 164. Best individuals: [152, 105, 104, 102, 96, 84, 80, 74, 72, 66, 52, 50, 36, 32, 32, 24, 24, 20, 18, 18]
# Mean best reward: 62.05
#
#  GENERATION 165
#
# 165. Best individuals: [216, 80, 72, 72, 56, 56, 54, 50, 48, 40, 38, 38, 36, 36, 28, 27, 25, 24, 24, 20]
# Mean best reward: 52.0
#
#  GENERATION 166
#
# 166. Best individuals: [138, 124, 121, 91, 48, 45, 44, 44, 40, 40, 38, 36, 32, 30, 28, 24, 20, 20, 20, 20]
# Mean best reward: 50.15
#
#  GENERATION 167
#
# 167. Best individuals: [144, 96, 73, 64, 62, 60, 48, 42, 40, 40, 36, 32, 32, 32, 26, 24, 22, 22, 18, 18]
# Mean best reward: 46.55
#
#  GENERATION 168
#
# 168. Best individuals: [153, 118, 115, 87, 68, 66, 64, 62, 52, 51, 48, 42, 40, 36, 36, 32, 30, 28, 24, 22]
# Mean best reward: 58.7
#
#  GENERATION 169
#
# 169. Best individuals: [148, 144, 144, 112, 78, 72, 60, 58, 57, 50, 48, 40, 40, 36, 35, 33, 28, 27, 24, 24]
# Mean best reward: 62.9
#
#  GENERATION 170
#
# 170. Best individuals: [152, 124, 124, 110, 98, 88, 64, 54, 48, 44, 40, 40, 36, 34, 34, 32, 30, 24, 24, 24]
# Mean best reward: 61.2
#
#  GENERATION 171
#
# 171. Best individuals: [88, 87, 78, 76, 66, 64, 62, 56, 56, 42, 36, 36, 34, 33, 32, 32, 32, 28, 27, 22]
# Mean best reward: 49.35
#
#  GENERATION 172
#
# 172. Best individuals: [148, 126, 60, 56, 52, 52, 48, 44, 42, 40, 40, 40, 36, 36, 27, 26, 24, 24, 24, 20]
# Mean best reward: 48.25
#
#  GENERATION 173
#
# 173. Best individuals: [113, 104, 100, 72, 48, 42, 40, 40, 39, 36, 36, 33, 32, 30, 28, 28, 24, 24, 24, 20]
# Mean best reward: 45.65
#
#  GENERATION 174
#
# 174. Best individuals: [196, 121, 102, 96, 88, 84, 64, 62, 60, 57, 40, 36, 36, 36, 36, 28, 28, 24, 24, 24]
# Mean best reward: 62.1
#
#  GENERATION 175
#
# 175. Best individuals: [96, 60, 56, 54, 48, 48, 48, 46, 40, 34, 30, 24, 24, 24, 21, 20, 20, 18, 18, 18]
# Mean best reward: 37.35
#
#  GENERATION 176
#
# 176. Best individuals: [108, 88, 72, 70, 66, 65, 57, 56, 56, 48, 45, 42, 40, 40, 36, 30, 28, 26, 24, 24]
# Mean best reward: 51.05
#
#  GENERATION 177
#
# 177. Best individuals: [188, 138, 124, 102, 100, 96, 90, 78, 70, 66, 64, 54, 48, 40, 36, 30, 30, 28, 24, 24]
# Mean best reward: 71.5
#
#  GENERATION 178
#
# 178. Best individuals: [156, 126, 106, 101, 96, 78, 72, 68, 52, 48, 48, 48, 44, 36, 36, 32, 30, 28, 20, 20]
# Mean best reward: 62.25
#
#  GENERATION 179
#
# 179. Best individuals: [72, 63, 60, 52, 44, 41, 40, 40, 40, 38, 36, 36, 32, 28, 28, 24, 24, 24, 21, 20]
# Mean best reward: 38.15
#
#  GENERATION 180
#
# 180. Best individuals: [100, 96, 96, 84, 77, 76, 66, 56, 54, 48, 48, 43, 42, 42, 40, 36, 32, 30, 26, 24]
# Mean best reward: 55.8
#
#  GENERATION 181
#
# 181. Best individuals: [148, 121, 84, 80, 60, 57, 52, 44, 42, 40, 40, 40, 40, 36, 34, 32, 32, 24, 24, 24]
# Mean best reward: 52.7
#
#  GENERATION 182
#
# 182. Best individuals: [194, 160, 144, 93, 76, 72, 72, 60, 56, 48, 48, 44, 44, 42, 32, 28, 28, 28, 24, 24]
# Mean best reward: 65.85
#
#  GENERATION 183
#
# 183. Best individuals: [116, 114, 92, 90, 66, 50, 50, 48, 32, 32, 30, 30, 28, 27, 26, 24, 24, 24, 24, 22]
# Mean best reward: 47.45
#
#  GENERATION 184
#
# 184. Best individuals: [154, 88, 84, 64, 60, 48, 47, 40, 39, 38, 36, 36, 36, 36, 30, 30, 27, 24, 20, 20]
# Mean best reward: 47.85
#
#  GENERATION 185
#
# 185. Best individuals: [118, 95, 87, 84, 84, 82, 80, 72, 68, 63, 60, 56, 48, 36, 32, 28, 27, 26, 24, 24]
# Mean best reward: 59.7
#
#  GENERATION 186
#
# 186. Best individuals: [186, 98, 63, 56, 56, 54, 54, 48, 48, 44, 36, 34, 34, 32, 28, 24, 22, 21, 20, 20]
# Mean best reward: 48.9
#
#  GENERATION 187
#
# 187. Best individuals: [131, 80, 78, 60, 48, 48, 48, 48, 46, 42, 36, 34, 33, 32, 32, 32, 30, 28, 28, 24]
# Mean best reward: 46.9
#
#  GENERATION 188
#
# 188. Best individuals: [182, 90, 85, 70, 64, 62, 56, 54, 50, 44, 42, 42, 40, 40, 40, 30, 24, 24, 24, 24]
# Mean best reward: 54.35
#
#  GENERATION 189
#
# 189. Best individuals: [123, 123, 116, 92, 88, 80, 80, 80, 78, 66, 60, 44, 44, 42, 40, 38, 36, 32, 24, 24]
# Mean best reward: 65.5
#
#  GENERATION 190
#
# 190. Best individuals: [143, 128, 120, 70, 60, 50, 48, 43, 40, 40, 36, 36, 32, 30, 27, 24, 24, 24, 22, 18]
# Mean best reward: 50.75
#
#  GENERATION 191
#
# 191. Best individuals: [126, 126, 104, 54, 49, 48, 48, 48, 40, 40, 36, 36, 32, 27, 24, 24, 24, 22, 20, 20]
# Mean best reward: 47.4
#
#  GENERATION 192
#
# 192. Best individuals: [84, 64, 59, 54, 50, 48, 46, 42, 40, 40, 40, 40, 39, 36, 28, 28, 24, 20, 20, 18]
# Mean best reward: 41.0
#
#  GENERATION 193
#
# 193. Best individuals: [132, 108, 88, 86, 66, 48, 48, 46, 42, 35, 34, 32, 32, 30, 30, 26, 24, 24, 22, 20]
# Mean best reward: 48.65
#
#  GENERATION 194
#
# 194. Best individuals: [198, 131, 118, 96, 94, 84, 82, 77, 76, 64, 56, 50, 46, 45, 42, 40, 40, 32, 32, 24]
# Mean best reward: 71.35
#
#  GENERATION 195
#
# 195. Best individuals: [154, 98, 84, 72, 70, 60, 60, 57, 54, 46, 44, 44, 39, 33, 32, 32, 30, 28, 24, 24]
# Mean best reward: 54.25
#
#  GENERATION 196
#
# 196. Best individuals: [224, 124, 112, 100, 96, 88, 88, 79, 60, 60, 54, 52, 45, 39, 36, 36, 32, 30, 24, 24]
# Mean best reward: 70.15
#
#  GENERATION 197
#
# 197. Best individuals: [176, 118, 84, 78, 72, 66, 66, 66, 60, 60, 54, 48, 48, 48, 36, 32, 32, 32, 24, 24]
# Mean best reward: 61.2
#
#  GENERATION 198
#
# 198. Best individuals: [88, 88, 87, 82, 72, 52, 48, 48, 48, 45, 42, 30, 30, 24, 24, 24, 24, 24, 20, 20]
# Mean best reward: 46.0
#
#  GENERATION 199
#
# 199. Best individuals: [96, 94, 90, 72, 64, 60, 46, 45, 44, 40, 36, 36, 28, 25, 24, 24, 24, 18, 18, 18]
# Mean best reward: 45.1
#
#  GENERATION 200
#
# 200. Best individuals: [126, 108, 101, 90, 88, 84, 60, 48, 44, 42, 42, 42, 42, 32, 32, 30, 24, 24, 24, 22]
# Mean best reward: 55.25
#
#  GENERATION 201
#
# 201. Best individuals: [158, 156, 154, 90, 84, 62, 48, 48, 44, 38, 36, 36, 36, 32, 32, 28, 24, 24, 24, 24]
# Mean best reward: 58.9
#
#  GENERATION 202
#
# 202. Best individuals: [160, 124, 109, 98, 93, 80, 80, 76, 60, 52, 52, 48, 36, 32, 28, 26, 24, 24, 24, 20]
# Mean best reward: 62.3
#
#  GENERATION 203
#
# 203. Best individuals: [144, 93, 91, 80, 74, 72, 68, 60, 56, 48, 36, 32, 30, 30, 30, 28, 24, 22, 20, 20]
# Mean best reward: 52.9
#
#  GENERATION 204
#
# 204. Best individuals: [163, 128, 88, 80, 76, 66, 60, 54, 51, 32, 32, 32, 27, 24, 24, 24, 24, 20, 18, 18]
# Mean best reward: 52.05
#
#  GENERATION 205
#
# 205. Best individuals: [161, 160, 120, 100, 91, 83, 75, 57, 48, 48, 40, 38, 32, 30, 26, 26, 24, 24, 24, 24]
# Mean best reward: 61.55
#
#  GENERATION 206
#
# 206. Best individuals: [170, 124, 101, 54, 54, 51, 48, 48, 42, 40, 30, 30, 30, 24, 24, 20, 20, 20, 18, 18]
# Mean best reward: 48.3
#
#  GENERATION 207
#
# 207. Best individuals: [138, 116, 76, 64, 54, 49, 48, 48, 46, 42, 40, 38, 36, 36, 34, 28, 24, 24, 24, 24]
# Mean best reward: 49.45
#
#  GENERATION 208
#
# 208. Best individuals: [208, 150, 65, 58, 54, 52, 50, 40, 39, 28, 28, 27, 25, 24, 24, 24, 24, 24, 24, 24]
# Mean best reward: 49.6
#
#  GENERATION 209
#
# 209. Best individuals: [160, 90, 88, 76, 60, 54, 50, 42, 36, 36, 36, 32, 30, 28, 24, 24, 24, 24, 24, 24]
# Mean best reward: 48.1
#
#  GENERATION 210
#
# 210. Best individuals: [184, 168, 107, 96, 94, 56, 56, 54, 44, 44, 43, 39, 36, 32, 30, 30, 30, 24, 20, 20]
# Mean best reward: 60.35
#
#  GENERATION 211
#
# 211. Best individuals: [152, 114, 96, 90, 72, 72, 59, 56, 50, 38, 36, 36, 36, 32, 30, 28, 24, 20, 18, 18]
# Mean best reward: 53.85
#
#  GENERATION 212
#
# 212. Best individuals: [141, 138, 75, 72, 66, 57, 55, 52, 50, 48, 48, 40, 40, 38, 32, 30, 24, 24, 24, 20]
# Mean best reward: 53.7
#
#  GENERATION 213
#
# 213. Best individuals: [128, 114, 92, 82, 68, 63, 56, 48, 48, 40, 36, 36, 36, 32, 32, 24, 24, 24, 24, 24]
# Mean best reward: 51.55
#
#  GENERATION 214
#
# 214. Best individuals: [128, 80, 78, 72, 65, 62, 54, 48, 48, 46, 42, 42, 36, 32, 32, 30, 28, 22, 20, 20]
# Mean best reward: 49.25
#
#  GENERATION 215
#
# 215. Best individuals: [126, 99, 72, 68, 60, 60, 60, 56, 54, 48, 45, 40, 40, 32, 32, 30, 28, 24, 24, 24]
# Mean best reward: 51.1
#
#  GENERATION 216
#
# 216. Best individuals: [132, 126, 78, 78, 68, 56, 54, 50, 48, 48, 48, 45, 42, 36, 36, 32, 30, 28, 28, 24]
# Mean best reward: 54.35
#
#  GENERATION 217
#
# 217. Best individuals: [174, 174, 123, 100, 90, 81, 73, 56, 54, 54, 48, 48, 48, 36, 30, 24, 24, 24, 24, 24]
# Mean best reward: 65.45
#
#  GENERATION 218
#
# 218. Best individuals: [176, 152, 126, 108, 98, 90, 69, 62, 56, 48, 42, 32, 32, 30, 30, 30, 24, 20, 20, 20]
# Mean best reward: 63.25
#
#  GENERATION 219
#
# 219. Best individuals: [120, 94, 92, 72, 63, 60, 48, 47, 44, 42, 40, 40, 40, 36, 30, 27, 26, 24, 24, 24]
# Mean best reward: 49.65
#
#  GENERATION 220
#
# 220. Best individuals: [116, 91, 88, 68, 68, 59, 58, 48, 42, 40, 40, 40, 36, 36, 32, 32, 30, 24, 24, 24]
# Mean best reward: 49.8
#
#  GENERATION 221
#
# 221. Best individuals: [89, 86, 84, 66, 64, 60, 56, 50, 48, 40, 36, 32, 28, 28, 24, 24, 22, 20, 16, 16]
# Mean best reward: 44.45
#
#  GENERATION 222
#
# 222. Best individuals: [150, 80, 78, 76, 72, 72, 66, 56, 56, 54, 48, 48, 46, 42, 36, 32, 24, 24, 24, 24]
# Mean best reward: 55.4
#
#  GENERATION 223
#
# 223. Best individuals: [132, 108, 105, 90, 88, 72, 72, 72, 69, 64, 48, 36, 36, 32, 30, 28, 28, 24, 22, 22]
# Mean best reward: 58.9
#
#  GENERATION 224
#
# 224. Best individuals: [219, 154, 134, 67, 58, 56, 49, 44, 44, 36, 36, 36, 30, 28, 28, 26, 26, 24, 24, 24]
# Mean best reward: 57.15
#
#  GENERATION 225
#
# 225. Best individuals: [180, 120, 106, 106, 84, 80, 68, 56, 54, 48, 48, 45, 36, 36, 34, 33, 32, 30, 24, 24]
# Mean best reward: 62.2
#
#  GENERATION 226
#
# 226. Best individuals: [178, 156, 112, 86, 68, 68, 60, 58, 58, 40, 36, 32, 32, 30, 24, 24, 22, 20, 18, 18]
# Mean best reward: 57.0
#
#  GENERATION 227
#
# 227. Best individuals: [152, 94, 72, 68, 62, 51, 34, 32, 30, 26, 24, 24, 24, 24, 24, 20, 20, 20, 18, 18]
# Mean best reward: 41.85
#
#  GENERATION 228
#
# 228. Best individuals: [290, 80, 76, 68, 64, 63, 60, 54, 48, 48, 48, 48, 44, 44, 44, 42, 40, 30, 26, 20]
# Mean best reward: 61.85
#
#  GENERATION 229
#
# 229. Best individuals: [132, 84, 82, 72, 71, 48, 44, 44, 42, 36, 28, 24, 24, 24, 24, 16, 16, 16, 16, 16]
# Mean best reward: 42.95
#
#  GENERATION 230
#
# 230. Best individuals: [216, 112, 108, 60, 56, 52, 52, 48, 40, 36, 32, 32, 30, 28, 24, 24, 24, 21, 20, 20]
# Mean best reward: 51.75
#
#  GENERATION 231
#
# 231. Best individuals: [132, 116, 76, 72, 72, 68, 64, 58, 56, 50, 48, 48, 44, 42, 40, 36, 32, 24, 24, 24]
# Mean best reward: 56.3
#
#  GENERATION 232
#
# 232. Best individuals: [166, 166, 140, 122, 110, 81, 72, 72, 64, 56, 40, 36, 36, 27, 24, 24, 24, 21, 16, 16]
# Mean best reward: 65.65
#
#  GENERATION 233
#
# 233. Best individuals: [113, 112, 98, 76, 66, 54, 53, 48, 38, 36, 36, 33, 32, 28, 24, 24, 24, 22, 20, 20]
# Mean best reward: 47.85
#
#  GENERATION 234
#
# 234. Best individuals: [156, 104, 100, 98, 86, 80, 74, 72, 58, 56, 52, 44, 42, 42, 40, 36, 30, 24, 24, 24]
# Mean best reward: 62.1
#
#  GENERATION 235
#
# 235. Best individuals: [146, 96, 64, 60, 60, 48, 44, 44, 42, 40, 38, 32, 32, 30, 28, 28, 25, 24, 24, 24]
# Mean best reward: 46.45
#
#  GENERATION 236
#
# 236. Best individuals: [192, 168, 150, 88, 84, 78, 72, 64, 60, 59, 52, 40, 32, 32, 28, 28, 28, 24, 24, 24]
# Mean best reward: 66.35
#
#  GENERATION 237
#
# 237. Best individuals: [160, 104, 96, 92, 84, 72, 64, 56, 54, 50, 47, 36, 36, 36, 36, 28, 26, 24, 24, 24]
# Mean best reward: 57.45
#
#  GENERATION 238
#
# 238. Best individuals: [196, 132, 125, 102, 76, 74, 72, 70, 62, 58, 48, 42, 42, 40, 36, 32, 32, 24, 24, 24]
# Mean best reward: 65.55
#
#  GENERATION 239
#
# 239. Best individuals: [170, 84, 60, 57, 46, 44, 42, 40, 40, 36, 36, 34, 32, 30, 28, 28, 26, 24, 20, 20]
# Mean best reward: 44.85
#
#  GENERATION 240
#
# 240. Best individuals: [200, 90, 84, 82, 72, 72, 66, 66, 54, 42, 40, 36, 32, 30, 28, 26, 24, 24, 24, 22]
# Mean best reward: 55.7
#
#  GENERATION 241
#
# 241. Best individuals: [130, 120, 81, 80, 72, 70, 57, 48, 48, 45, 40, 40, 40, 39, 36, 36, 36, 32, 32, 24]
# Mean best reward: 55.3
#
#  GENERATION 242
#
# 242. Best individuals: [104, 96, 77, 68, 60, 56, 48, 42, 40, 40, 35, 32, 32, 32, 32, 28, 28, 24, 24, 24]
# Mean best reward: 46.1
#
#  GENERATION 243
#
# 243. Best individuals: [242, 96, 72, 60, 48, 46, 40, 40, 36, 36, 36, 32, 32, 30, 30, 28, 28, 24, 24, 24]
# Mean best reward: 50.2
#
#  GENERATION 244
#
# 244. Best individuals: [204, 150, 130, 114, 68, 65, 64, 60, 54, 52, 40, 40, 32, 30, 26, 25, 24, 24, 22, 20]
# Mean best reward: 62.2
#
#  GENERATION 245
#
# 245. Best individuals: [200, 114, 109, 105, 100, 84, 75, 66, 62, 60, 59, 52, 50, 48, 42, 40, 32, 28, 24, 24]
# Mean best reward: 68.7
#
#  GENERATION 246
#
# 246. Best individuals: [192, 182, 176, 155, 138, 116, 81, 75, 56, 56, 54, 48, 44, 42, 32, 28, 24, 24, 24, 24]
# Mean best reward: 78.55
#
#  GENERATION 247
#
# 247. Best individuals: [216, 148, 109, 100, 70, 56, 56, 48, 40, 40, 36, 32, 32, 32, 30, 30, 28, 24, 24, 24]
# Mean best reward: 58.75
#
#  GENERATION 248
#
# 248. Best individuals: [156, 132, 126, 84, 80, 70, 54, 44, 42, 40, 39, 36, 36, 36, 32, 30, 30, 28, 24, 24]
# Mean best reward: 57.15
#
#  GENERATION 249
#
# 249. Best individuals: [162, 126, 104, 80, 78, 45, 38, 36, 33, 32, 32, 32, 24, 24, 24, 20, 20, 18, 16, 16]
# Mean best reward: 48.0
#
#  GENERATION 250
#
# 250. Best individuals: [120, 115, 90, 88, 86, 84, 81, 80, 80, 72, 48, 47, 45, 40, 40, 36, 32, 30, 28, 24]
# Mean best reward: 63.3
#
#  GENERATION 251
#
# 251. Best individuals: [112, 112, 90, 80, 76, 60, 60, 60, 60, 46, 45, 42, 34, 32, 32, 30, 26, 24, 24, 24]
# Mean best reward: 53.45
#
#  GENERATION 252
#
# 252. Best individuals: [78, 74, 74, 72, 66, 60, 54, 50, 48, 36, 32, 32, 32, 32, 24, 24, 24, 20, 20, 18]
# Mean best reward: 43.5
#
#  GENERATION 253
#
# 253. Best individuals: [172, 156, 107, 102, 99, 92, 82, 72, 56, 56, 40, 39, 36, 36, 36, 32, 32, 32, 28, 24]
# Mean best reward: 66.45
#
#  GENERATION 254
#
# 254. Best individuals: [160, 116, 96, 90, 88, 70, 68, 66, 50, 48, 48, 48, 44, 42, 40, 33, 26, 24, 24, 24]
# Mean best reward: 60.25
#
#  GENERATION 255
#
# 255. Best individuals: [112, 90, 72, 69, 56, 56, 52, 50, 50, 48, 48, 40, 40, 28, 27, 27, 27, 24, 24, 24]
# Mean best reward: 48.2
#
#  GENERATION 256
#
# 256. Best individuals: [148, 98, 96, 92, 88, 80, 72, 72, 66, 56, 52, 52, 45, 40, 40, 32, 32, 28, 26, 24]
# Mean best reward: 61.95
#
#  GENERATION 257
#
# 257. Best individuals: [210, 144, 138, 125, 109, 96, 88, 80, 72, 72, 70, 68, 53, 48, 42, 42, 40, 36, 24, 24]
# Mean best reward: 79.05
#
#  GENERATION 258
#
# 258. Best individuals: [144, 126, 75, 74, 72, 64, 56, 54, 52, 51, 48, 48, 40, 36, 36, 30, 30, 28, 24, 22]
# Mean best reward: 55.5
#
#  GENERATION 259
#
# 259. Best individuals: [196, 156, 126, 60, 60, 56, 54, 52, 52, 52, 44, 40, 32, 32, 27, 26, 24, 24, 24, 24]
# Mean best reward: 58.05
#
#  GENERATION 260
#
# 260. Best individuals: [109, 98, 96, 96, 84, 78, 56, 48, 44, 42, 34, 34, 32, 32, 32, 32, 26, 24, 24, 24]
# Mean best reward: 52.25
#
#  GENERATION 261
#
# 261. Best individuals: [102, 96, 66, 64, 56, 53, 52, 49, 48, 46, 42, 36, 28, 28, 25, 24, 20, 20, 18, 18]
# Mean best reward: 44.55
#
#  GENERATION 262
#
# 262. Best individuals: [234, 153, 88, 55, 54, 42, 40, 40, 36, 32, 32, 32, 30, 27, 24, 24, 24, 24, 24, 20]
# Mean best reward: 51.75
#
#  GENERATION 263
#
# 263. Best individuals: [202, 72, 69, 64, 60, 56, 45, 44, 42, 40, 38, 36, 32, 32, 30, 24, 24, 24, 24, 24]
# Mean best reward: 49.1
#
#  GENERATION 264
#
# 264. Best individuals: [144, 126, 96, 81, 80, 70, 42, 42, 32, 28, 28, 28, 20, 18, 18, 18, 18, 18, 18, 18]
# Mean best reward: 47.15
#
#  GENERATION 265
#
# 265. Best individuals: [72, 54, 42, 40, 36, 36, 32, 32, 32, 28, 28, 28, 24, 24, 24, 24, 20, 20, 20, 18]
# Mean best reward: 31.7
#
#  GENERATION 266
#
# 266. Best individuals: [144, 140, 101, 84, 82, 72, 70, 56, 52, 44, 40, 36, 32, 32, 30, 24, 24, 20, 20, 20]
# Mean best reward: 56.15
#
#  GENERATION 267
#
# 267. Best individuals: [193, 152, 108, 105, 103, 78, 54, 51, 48, 45, 40, 36, 30, 26, 24, 24, 24, 24, 20, 20]
# Mean best reward: 60.25
#
#  GENERATION 268
#
# 268. Best individuals: [168, 128, 90, 86, 84, 82, 68, 60, 60, 48, 48, 45, 40, 40, 36, 36, 32, 32, 30, 30]
# Mean best reward: 62.15
#
#  GENERATION 269
#
# 269. Best individuals: [164, 140, 108, 102, 94, 94, 88, 84, 70, 51, 48, 48, 40, 36, 36, 32, 30, 25, 24, 24]
# Mean best reward: 66.9
#
#  GENERATION 270
#
# 270. Best individuals: [136, 116, 90, 88, 80, 78, 76, 72, 72, 72, 64, 38, 36, 30, 28, 26, 21, 20, 20, 20]
# Mean best reward: 59.15
#
#  GENERATION 271
#
# 271. Best individuals: [184, 150, 86, 84, 56, 55, 54, 54, 48, 42, 40, 36, 36, 36, 34, 32, 30, 30, 28, 24]
# Mean best reward: 56.95
#
#  GENERATION 272
#
# 272. Best individuals: [88, 76, 44, 42, 40, 36, 34, 30, 30, 28, 24, 24, 24, 24, 20, 20, 18, 18, 18, 18]
# Mean best reward: 32.8
#
#  GENERATION 273
#
# 273. Best individuals: [156, 144, 120, 74, 64, 60, 60, 58, 56, 54, 51, 46, 45, 45, 40, 36, 36, 36, 32, 24]
# Mean best reward: 61.85
#
#  GENERATION 274
#
# 274. Best individuals: [158, 144, 120, 111, 93, 86, 72, 62, 51, 40, 36, 36, 36, 32, 32, 32, 27, 24, 24, 24]
# Mean best reward: 62.0
#
#  GENERATION 275
#
# 275. Best individuals: [112, 102, 84, 72, 56, 54, 51, 50, 48, 44, 42, 40, 32, 32, 30, 28, 24, 24, 24, 24]
# Mean best reward: 48.65
#
#  GENERATION 276
#
# 276. Best individuals: [204, 176, 117, 112, 70, 70, 60, 52, 48, 48, 42, 40, 40, 34, 30, 24, 24, 24, 24, 24]
# Mean best reward: 63.15
#
#  GENERATION 277
#
# 277. Best individuals: [180, 140, 136, 112, 84, 68, 58, 57, 56, 46, 40, 36, 32, 30, 30, 28, 28, 24, 24, 22]
# Mean best reward: 61.55
#
#  GENERATION 278
#
# 278. Best individuals: [146, 90, 74, 70, 56, 51, 50, 48, 44, 40, 40, 36, 32, 30, 28, 20, 18, 18, 18, 16]
# Mean best reward: 46.25
#
#  GENERATION 279
#
# 279. Best individuals: [112, 112, 96, 80, 63, 50, 48, 46, 40, 36, 34, 33, 32, 28, 24, 20, 18, 16, 16, 16]
# Mean best reward: 46.0
#
#  GENERATION 280
#
# 280. Best individuals: [201, 110, 110, 80, 71, 56, 54, 50, 49, 48, 42, 36, 32, 30, 30, 24, 24, 21, 20, 18]
# Mean best reward: 55.3
#
#  GENERATION 281
#
# 281. Best individuals: [204, 176, 108, 100, 96, 90, 84, 60, 56, 56, 48, 46, 42, 40, 40, 38, 32, 32, 32, 24]
# Mean best reward: 70.2
#
#  GENERATION 282
#
# 282. Best individuals: [128, 114, 76, 76, 72, 56, 56, 56, 48, 46, 45, 42, 36, 36, 32, 30, 28, 28, 28, 24]
# Mean best reward: 52.85
#
#  GENERATION 283
#
# 283. Best individuals: [178, 131, 108, 97, 78, 76, 75, 70, 64, 55, 54, 40, 40, 36, 36, 35, 24, 24, 24, 24]
# Mean best reward: 63.45
#
#  GENERATION 284
#
# 284. Best individuals: [169, 116, 92, 80, 72, 70, 56, 56, 40, 34, 32, 30, 28, 24, 24, 24, 24, 20, 18, 18]
# Mean best reward: 51.35
#
#  GENERATION 285
#
# 285. Best individuals: [182, 144, 130, 88, 80, 80, 76, 70, 60, 57, 56, 36, 36, 32, 28, 27, 24, 24, 24, 22]
# Mean best reward: 63.8
#
#  GENERATION 286
#
# 286. Best individuals: [84, 84, 80, 78, 76, 69, 62, 55, 54, 54, 48, 44, 40, 40, 36, 36, 36, 34, 32, 20]
# Mean best reward: 53.1
#
#  GENERATION 287
#
# 287. Best individuals: [216, 88, 72, 68, 52, 52, 50, 48, 48, 42, 42, 36, 32, 28, 24, 24, 24, 24, 20, 20]
# Mean best reward: 50.5
#
#  GENERATION 288
#
# 288. Best individuals: [112, 96, 95, 85, 80, 78, 68, 56, 48, 44, 44, 42, 40, 36, 36, 36, 30, 30, 28, 24]
# Mean best reward: 55.4
#
#  GENERATION 289
#
# 289. Best individuals: [217, 190, 162, 116, 108, 104, 100, 96, 86, 85, 81, 60, 58, 54, 38, 32, 32, 24, 24, 24]
# Mean best reward: 84.55
#
#  GENERATION 290
#
# 290. Best individuals: [115, 97, 88, 76, 64, 57, 56, 50, 48, 44, 44, 32, 28, 28, 24, 24, 24, 24, 22, 22]
# Mean best reward: 48.35
#
#  GENERATION 291
#
# 291. Best individuals: [142, 126, 126, 102, 96, 76, 71, 62, 55, 38, 36, 32, 32, 30, 30, 24, 24, 24, 20, 20]
# Mean best reward: 58.3
#
#  GENERATION 292
#
# 292. Best individuals: [131, 109, 88, 86, 80, 73, 63, 56, 50, 40, 36, 36, 34, 28, 27, 26, 24, 24, 20, 20]
# Mean best reward: 52.55
#
#  GENERATION 293
#
# 293. Best individuals: [245, 98, 96, 75, 62, 56, 52, 48, 44, 40, 34, 32, 32, 32, 30, 30, 30, 28, 24, 24]
# Mean best reward: 55.6
#
#  GENERATION 294
#
# 294. Best individuals: [128, 108, 102, 92, 88, 68, 56, 48, 42, 42, 36, 32, 32, 30, 30, 24, 24, 24, 24, 24]
# Mean best reward: 52.7
#
#  GENERATION 295
#
# 295. Best individuals: [116, 80, 78, 72, 64, 50, 48, 48, 44, 36, 36, 28, 24, 24, 24, 24, 24, 24, 24, 18]
# Mean best reward: 44.3
#
#  GENERATION 296
#
# 296. Best individuals: [133, 114, 64, 60, 60, 48, 48, 48, 48, 42, 36, 34, 32, 30, 30, 28, 24, 24, 24, 24]
# Mean best reward: 47.55
#
#  GENERATION 297
#
# 297. Best individuals: [172, 94, 83, 72, 72, 70, 68, 65, 64, 48, 42, 42, 38, 36, 36, 36, 32, 32, 30, 24]
# Mean best reward: 57.8
#
#  GENERATION 298
#
# 298. Best individuals: [192, 176, 162, 154, 142, 96, 80, 75, 70, 68, 52, 52, 50, 36, 33, 32, 30, 24, 24, 20]
# Mean best reward: 78.4
#
#  GENERATION 299
#
# 299. Best individuals: [168, 140, 120, 104, 101, 75, 69, 61, 58, 47, 45, 36, 32, 28, 28, 24, 24, 24, 24, 20]
# Mean best reward: 61.4
#
#  GENERATION 300
#
# 300. Best individuals: [184, 144, 126, 114, 101, 92, 75, 60, 56, 46, 44, 42, 40, 40, 36, 27, 24, 24, 24, 24]
# Mean best reward: 66.15
#
#  GENERATION 301
#
# 301. Best individuals: [154, 133, 100, 72, 72, 60, 54, 46, 46, 44, 32, 32, 32, 26, 24, 24, 24, 24, 24, 22]
# Mean best reward: 52.25
#
#  GENERATION 302
#
# 302. Best individuals: [147, 116, 78, 78, 72, 60, 60, 56, 56, 50, 50, 44, 36, 32, 32, 32, 30, 27, 24, 24]
# Mean best reward: 55.2
#
#  GENERATION 303
#
# 303. Best individuals: [187, 70, 68, 64, 60, 56, 48, 48, 40, 32, 32, 32, 32, 30, 30, 28, 28, 25, 24, 24]
# Mean best reward: 47.9
#
#  GENERATION 304
#
# 304. Best individuals: [111, 108, 102, 94, 92, 90, 90, 66, 56, 51, 40, 36, 32, 32, 32, 30, 28, 28, 27, 24]
# Mean best reward: 58.45
#
#  GENERATION 305
#
# 305. Best individuals: [203, 184, 178, 128, 111, 98, 94, 73, 63, 58, 54, 52, 48, 48, 36, 36, 28, 24, 24, 24]
# Mean best reward: 78.2
#
#  GENERATION 306
#
# 306. Best individuals: [96, 96, 84, 81, 78, 76, 72, 68, 63, 57, 46, 42, 42, 40, 34, 34, 32, 32, 24, 24]
# Mean best reward: 56.05
#
#  GENERATION 307
#
# 307. Best individuals: [132, 96, 87, 84, 76, 69, 48, 48, 42, 40, 40, 38, 36, 32, 32, 24, 22, 20, 18, 18]
# Mean best reward: 50.1
#
#  GENERATION 308
#
# 308. Best individuals: [147, 127, 106, 56, 46, 38, 36, 36, 36, 32, 32, 30, 27, 24, 24, 24, 24, 24, 22, 20]
# Mean best reward: 45.55
#
#  GENERATION 309
#
# 309. Best individuals: [180, 132, 107, 97, 80, 72, 64, 45, 40, 36, 36, 34, 32, 32, 30, 30, 28, 22, 20, 18]
# Mean best reward: 56.75
#
#  GENERATION 310
#
# 310. Best individuals: [195, 157, 138, 76, 68, 64, 57, 48, 44, 36, 36, 32, 30, 30, 28, 27, 26, 24, 24, 22]
# Mean best reward: 58.1
#
#  GENERATION 311
#
# 311. Best individuals: [138, 118, 91, 90, 67, 60, 54, 54, 54, 48, 43, 42, 39, 36, 32, 32, 32, 32, 28, 24]
# Mean best reward: 55.7
#
#  GENERATION 312
#
# 312. Best individuals: [99, 78, 71, 64, 56, 53, 48, 46, 46, 44, 36, 36, 34, 32, 32, 27, 24, 24, 20, 20]
# Mean best reward: 44.5
#
#  GENERATION 313
#
# 313. Best individuals: [132, 104, 85, 80, 80, 68, 54, 48, 44, 36, 32, 32, 32, 30, 28, 26, 24, 24, 16, 16]
# Mean best reward: 49.55
#
#  GENERATION 314
#
# 314. Best individuals: [104, 100, 88, 78, 73, 58, 54, 48, 45, 42, 42, 42, 40, 36, 36, 32, 24, 24, 24, 24]
# Mean best reward: 50.7
#
#  GENERATION 315
#
# 315. Best individuals: [144, 122, 118, 104, 70, 66, 64, 60, 58, 56, 53, 48, 44, 40, 36, 33, 32, 24, 24, 20]
# Mean best reward: 60.8
#
#  GENERATION 316
#
# 316. Best individuals: [116, 101, 96, 90, 82, 66, 56, 44, 39, 32, 28, 28, 24, 24, 24, 24, 24, 24, 24, 24]
# Mean best reward: 48.5
#
#  GENERATION 317
#
# 317. Best individuals: [156, 148, 125, 88, 87, 84, 72, 52, 44, 32, 32, 32, 30, 30, 24, 24, 24, 24, 24, 24]
# Mean best reward: 57.8
#
#  GENERATION 318
#
# 318. Best individuals: [100, 95, 85, 84, 80, 66, 64, 62, 51, 42, 38, 36, 36, 36, 36, 26, 24, 24, 22, 20]
# Mean best reward: 51.35
#
#  GENERATION 319
#
# 319. Best individuals: [103, 90, 78, 64, 63, 62, 60, 52, 52, 48, 42, 40, 40, 36, 30, 30, 26, 24, 24, 20]
# Mean best reward: 49.2
#
#  GENERATION 320
#
# 320. Best individuals: [208, 164, 164, 132, 107, 96, 96, 78, 77, 76, 71, 66, 63, 60, 56, 32, 30, 30, 24, 24]
# Mean best reward: 82.7
#
#  GENERATION 321
#
# 321. Best individuals: [140, 114, 99, 96, 88, 84, 76, 72, 56, 49, 48, 46, 44, 40, 39, 36, 28, 24, 24, 24]
# Mean best reward: 61.35
#
#  GENERATION 322
#
# 322. Best individuals: [136, 110, 88, 88, 68, 63, 54, 54, 48, 44, 42, 33, 32, 32, 28, 28, 24, 24, 24, 24]
# Mean best reward: 52.2
#
#  GENERATION 323
#
# 323. Best individuals: [168, 120, 104, 96, 93, 72, 64, 36, 36, 32, 32, 30, 28, 28, 24, 24, 24, 24, 24, 24]
# Mean best reward: 54.15
#
#  GENERATION 324
#
# 324. Best individuals: [312, 187, 128, 119, 114, 110, 105, 84, 81, 48, 45, 42, 40, 40, 40, 36, 27, 24, 24, 22]
# Mean best reward: 81.4
#
#  GENERATION 325
#
# 325. Best individuals: [197, 180, 136, 102, 85, 67, 56, 54, 48, 46, 42, 36, 32, 28, 28, 26, 24, 24, 24, 24]
# Mean best reward: 62.95
#
#  GENERATION 326
#
# 326. Best individuals: [138, 133, 88, 66, 62, 55, 44, 40, 36, 36, 34, 32, 24, 24, 20, 18, 18, 18, 18, 16]
# Mean best reward: 46.0
#
#  GENERATION 327
#
# ...
# Mean best reward: 67.6
#
#  GENERATION 2404
#
# 2404. Best individuals: [250, 192, 126, 119, 96, 84, 82, 80, 64, 48, 48, 44, 36, 36, 32, 32, 30, 28, 26, 24]
# Mean best reward: 73.85
#
#  GENERATION 2405
#
# 2405. Best individuals: [114, 84, 80, 68, 66, 64, 60, 51, 48, 48, 42, 36, 32, 32, 28, 28, 26, 24, 24, 18]
# Mean best reward: 48.65
#
#  GENERATION 2406
#
# 2406. Best individuals: [200, 96, 90, 72, 66, 64, 54, 51, 50, 48, 48, 40, 39, 38, 26, 24, 22, 20, 18, 18]
# Mean best reward: 54.2
#
#  GENERATION 2407
#
# 2407. Best individuals: [148, 72, 72, 60, 54, 45, 40, 36, 36, 33, 32, 32, 28, 28, 24, 24, 24, 24, 24, 18]
# Mean best reward: 42.7
#
#  GENERATION 2408
#
# 2408. Best individuals: [148, 108, 108, 108, 104, 96, 95, 82, 72, 68, 48, 48, 48, 48, 45, 44, 40, 30, 28, 24]
# Mean best reward: 69.6
#
#  GENERATION 2409
#
# 2409. Best individuals: [149, 94, 88, 80, 74, 66, 57, 51, 42, 42, 40, 40, 36, 32, 24, 24, 24, 24, 24, 24]
# Mean best reward: 51.75
#
#  GENERATION 2410
#
# 2410. Best individuals: [224, 126, 117, 117, 93, 90, 88, 72, 56, 56, 52, 48, 48, 40, 36, 36, 30, 24, 24, 24]
# Mean best reward: 70.05
#
#  GENERATION 2411
#
# 2411. Best individuals: [131, 122, 90, 79, 68, 48, 48, 48, 44, 44, 31, 28, 28, 24, 24, 24, 24, 20, 20, 16]
# Mean best reward: 48.05
#
#  GENERATION 2412
#
# 2412. Best individuals: [156, 110, 95, 89, 81, 68, 66, 60, 56, 48, 48, 36, 32, 32, 28, 28, 24, 24, 22, 18]
# Mean best reward: 56.05
#
#  GENERATION 2413
#
# 2413. Best individuals: [329, 248, 164, 158, 142, 114, 102, 91, 88, 84, 76, 76, 60, 36, 35, 32, 24, 18, 18, 18]
# Mean best reward: 95.65
#
#  GENERATION 2414
#
# 2414. Best individuals: [112, 100, 96, 88, 64, 54, 48, 48, 44, 42, 36, 32, 30, 30, 28, 24, 24, 24, 24, 24]
# Mean best reward: 48.6
#
#  GENERATION 2415
#
# 2415. Best individuals: [198, 192, 136, 120, 96, 93, 76, 72, 68, 66, 63, 60, 56, 56, 48, 36, 32, 32, 24, 24]
# Mean best reward: 77.4
#
#  GENERATION 2416
#
# 2416. Best individuals: [190, 122, 120, 114, 78, 66, 54, 51, 48, 48, 44, 42, 36, 36, 36, 36, 24, 24, 24, 24]
# Mean best reward: 60.85
#
#  GENERATION 2417
#
# 2417. Best individuals: [170, 126, 104, 98, 76, 68, 66, 62, 56, 51, 48, 48, 48, 45, 42, 42, 32, 30, 27, 24]
# Mean best reward: 63.15
#
#  GENERATION 2418
#
# 2418. Best individuals: [172, 162, 140, 125, 115, 96, 88, 81, 80, 76, 56, 50, 48, 42, 40, 36, 32, 30, 24, 24]
# Mean best reward: 75.85
#
#  GENERATION 2419
#
# 2419. Best individuals: [242, 238, 194, 176, 99, 92, 84, 66, 58, 52, 46, 42, 42, 42, 40, 39, 24, 24, 24, 24]
# Mean best reward: 82.4
#
#  GENERATION 2420
#
# 2420. Best individuals: [130, 128, 126, 100, 97, 84, 66, 56, 54, 52, 48, 48, 42, 32, 32, 30, 28, 24, 24, 24]
# Mean best reward: 61.25
#
#  GENERATION 2421
#
# 2421. Best individuals: [127, 124, 76, 72, 72, 72, 68, 66, 66, 48, 48, 48, 48, 48, 44, 30, 30, 28, 24, 24]
# Mean best reward: 58.15
#
#  GENERATION 2422
#
# 2422. Best individuals: [158, 96, 68, 66, 64, 52, 49, 42, 40, 36, 34, 32, 32, 30, 30, 24, 24, 24, 20, 20]
# Mean best reward: 47.05
#
#  GENERATION 2423
#
# 2423. Best individuals: [99, 88, 84, 72, 72, 62, 54, 53, 46, 44, 42, 42, 42, 40, 36, 30, 28, 27, 24, 24]
# Mean best reward: 50.45
#
#  GENERATION 2424
#
# 2424. Best individuals: [150, 134, 128, 104, 100, 84, 72, 64, 60, 56, 53, 48, 48, 42, 42, 40, 40, 36, 36, 24]
# Mean best reward: 68.05
#
#  GENERATION 2425
#
# 2425. Best individuals: [111, 95, 90, 90, 90, 54, 54, 48, 48, 44, 39, 36, 32, 32, 32, 30, 28, 26, 24, 24]
# Mean best reward: 51.35
#
#  GENERATION 2426
#
# 2426. Best individuals: [144, 122, 104, 72, 72, 66, 60, 56, 55, 48, 48, 45, 36, 32, 32, 28, 24, 24, 24, 24]
# Mean best reward: 55.8
#
#  GENERATION 2427
#
# 2427. Best individuals: [138, 112, 103, 86, 66, 60, 56, 56, 52, 48, 48, 45, 44, 30, 27, 24, 22, 20, 18, 18]
# Mean best reward: 53.65
#
#  GENERATION 2428
#
# 2428. Best individuals: [204, 132, 102, 84, 80, 80, 72, 64, 46, 36, 36, 36, 28, 26, 24, 22, 20, 20, 18, 18]
# Mean best reward: 57.4
#
#  GENERATION 2429
#
# 2429. Best individuals: [165, 108, 96, 70, 61, 60, 60, 56, 54, 42, 42, 38, 32, 30, 28, 24, 24, 24, 24, 24]
# Mean best reward: 53.1
#
#  GENERATION 2430
#
# 2430. Best individuals: [234, 161, 115, 100, 84, 80, 64, 58, 56, 52, 44, 40, 38, 32, 24, 24, 24, 24, 24, 20]
# Mean best reward: 64.9
#
#  GENERATION 2431
#
# 2431. Best individuals: [72, 70, 60, 58, 58, 56, 56, 54, 40, 38, 36, 28, 27, 24, 24, 24, 20, 20, 20, 20]
# Mean best reward: 40.25
#
#  GENERATION 2432
#
# 2432. Best individuals: [150, 137, 84, 74, 60, 57, 50, 48, 48, 40, 39, 36, 34, 32, 26, 24, 24, 24, 24, 24]
# Mean best reward: 51.75
#
#  GENERATION 2433
#
# 2433. Best individuals: [138, 132, 119, 104, 91, 90, 80, 64, 60, 54, 52, 40, 36, 32, 32, 30, 30, 24, 24, 24]
# Mean best reward: 62.8
#
#  GENERATION 2434
#
# 2434. Best individuals: [108, 108, 95, 80, 72, 64, 56, 56, 52, 48, 40, 34, 32, 28, 28, 26, 24, 24, 24, 20]
# Mean best reward: 50.95
#
#  GENERATION 2435
#
# 2435. Best individuals: [220, 168, 128, 124, 98, 90, 86, 80, 78, 70, 64, 56, 54, 48, 40, 36, 32, 30, 24, 24]
# Mean best reward: 77.5
#
#  GENERATION 2436
#
# 2436. Best individuals: [152, 112, 90, 80, 72, 68, 66, 56, 48, 48, 40, 40, 36, 32, 32, 30, 24, 24, 20, 20]
# Mean best reward: 54.5
#
#  GENERATION 2437
#
# 2437. Best individuals: [168, 108, 100, 100, 92, 78, 71, 60, 60, 52, 42, 36, 28, 28, 24, 24, 24, 24, 20, 20]
# Mean best reward: 57.95
#
#  GENERATION 2438
#
# 2438. Best individuals: [194, 156, 118, 100, 93, 78, 78, 78, 72, 64, 60, 59, 58, 56, 56, 36, 30, 28, 24, 20]
# Mean best reward: 72.9
#
#  GENERATION 2439
#
# 2439. Best individuals: [101, 91, 84, 84, 54, 52, 51, 46, 44, 44, 44, 38, 32, 30, 27, 24, 24, 24, 24, 24]
# Mean best reward: 47.1
#
#  GENERATION 2440
#
# 2440. Best individuals: [120, 116, 82, 57, 57, 52, 51, 48, 48, 40, 36, 34, 32, 32, 30, 24, 24, 20, 18, 18]
# Mean best reward: 46.95
#
#  GENERATION 2441
#
# 2441. Best individuals: [140, 117, 96, 84, 68, 56, 52, 48, 48, 48, 48, 45, 32, 30, 28, 28, 24, 24, 24, 20]
# Mean best reward: 53.0
#
#  GENERATION 2442
#
# 2442. Best individuals: [174, 128, 110, 99, 90, 86, 80, 78, 72, 42, 40, 36, 32, 30, 24, 24, 24, 20, 16, 16]
# Mean best reward: 61.05
#
#  GENERATION 2443
#
# 2443. Best individuals: [198, 176, 120, 88, 86, 60, 58, 56, 48, 43, 40, 32, 32, 32, 30, 30, 24, 24, 22, 18]
# Mean best reward: 60.85
#
#  GENERATION 2444
#
# 2444. Best individuals: [173, 148, 126, 104, 92, 84, 80, 60, 48, 44, 42, 42, 40, 36, 34, 32, 28, 24, 24, 24]
# Mean best reward: 64.25
#
#  GENERATION 2445
#
# 2445. Best individuals: [140, 118, 109, 91, 88, 84, 72, 64, 60, 50, 48, 40, 40, 36, 36, 36, 32, 32, 26, 24]
# Mean best reward: 61.3
#
#  GENERATION 2446
#
# 2446. Best individuals: [164, 137, 120, 96, 84, 76, 66, 56, 36, 36, 32, 32, 32, 32, 28, 24, 24, 22, 18, 18]
# Mean best reward: 56.65
#
#  GENERATION 2447
#
# 2447. Best individuals: [221, 121, 112, 100, 82, 60, 54, 52, 51, 45, 40, 34, 32, 32, 30, 28, 28, 24, 24, 24]
# Mean best reward: 59.7
#
#  GENERATION 2448
#
# 2448. Best individuals: [160, 102, 90, 81, 72, 68, 64, 59, 56, 48, 48, 40, 40, 39, 38, 36, 32, 28, 24, 24]
# Mean best reward: 57.45
#
#  GENERATION 2449
#
# 2449. Best individuals: [195, 152, 122, 84, 80, 76, 60, 60, 56, 48, 48, 44, 40, 32, 28, 26, 24, 24, 22, 22]
# Mean best reward: 62.15
#
#  GENERATION 2450
#
# 2450. Best individuals: [132, 127, 105, 90, 84, 48, 40, 36, 32, 32, 30, 24, 24, 24, 24, 24, 24, 21, 20, 20]
# Mean best reward: 48.05
#
#  GENERATION 2451
#
# 2451. Best individuals: [148, 137, 96, 83, 72, 64, 54, 52, 48, 48, 48, 40, 36, 36, 32, 24, 24, 18, 16, 16]
# Mean best reward: 54.6
#
#  GENERATION 2452
#
# 2452. Best individuals: [144, 104, 98, 66, 48, 45, 38, 36, 36, 36, 34, 33, 32, 32, 32, 30, 24, 24, 22, 21]
# Mean best reward: 46.75
#
#  GENERATION 2453
#
# 2453. Best individuals: [104, 96, 76, 64, 64, 62, 56, 56, 54, 40, 38, 36, 32, 30, 28, 24, 24, 24, 20, 18]
# Mean best reward: 47.3
#
#  GENERATION 2454
#
# 2454. Best individuals: [156, 137, 106, 100, 82, 80, 64, 60, 44, 40, 36, 33, 32, 32, 30, 24, 24, 24, 24, 24]
# Mean best reward: 57.6
#
#  GENERATION 2455
#
# 2455. Best individuals: [95, 85, 84, 72, 72, 64, 58, 52, 46, 40, 38, 36, 32, 30, 28, 28, 26, 26, 24, 24]
# Mean best reward: 48.0
#
#  GENERATION 2456
#
# 2456. Best individuals: [156, 107, 91, 87, 72, 68, 64, 64, 60, 54, 48, 44, 34, 32, 32, 30, 24, 24, 20, 20]
# Mean best reward: 56.55
#
#  GENERATION 2457
#
# 2457. Best individuals: [233, 192, 142, 96, 84, 78, 76, 75, 74, 63, 56, 48, 48, 32, 32, 24, 24, 22, 20, 20]
# Mean best reward: 71.95
#
#  GENERATION 2458
#
# 2458. Best individuals: [160, 148, 114, 96, 92, 90, 80, 66, 62, 60, 51, 40, 36, 32, 27, 26, 26, 24, 24, 24]
# Mean best reward: 63.9
#
#  GENERATION 2459
#
# 2459. Best individuals: [162, 144, 130, 128, 118, 104, 91, 48, 44, 42, 36, 36, 36, 36, 34, 28, 28, 24, 24, 24]
# Mean best reward: 65.85
#
#  GENERATION 2460
#
# 2460. Best individuals: [280, 112, 108, 84, 80, 70, 56, 42, 40, 32, 30, 30, 28, 28, 24, 24, 24, 24, 24, 24]
# Mean best reward: 58.2
#
#  GENERATION 2461
#
# 2461. Best individuals: [156, 153, 108, 96, 80, 65, 63, 52, 52, 50, 40, 36, 36, 32, 32, 30, 24, 24, 20, 18]
# Mean best reward: 58.35
#
#  GENERATION 2462
#
# 2462. Best individuals: [111, 96, 80, 68, 62, 56, 56, 48, 48, 48, 48, 46, 42, 40, 36, 34, 32, 24, 24, 24]
# Mean best reward: 51.15
#
#  GENERATION 2463
#
# 2463. Best individuals: [198, 102, 76, 76, 66, 63, 62, 60, 56, 54, 52, 44, 42, 36, 36, 36, 28, 28, 24, 20]
# Mean best reward: 57.95
#
#  GENERATION 2464
#
# 2464. Best individuals: [189, 162, 138, 112, 76, 70, 60, 52, 48, 45, 44, 43, 40, 32, 30, 28, 24, 24, 24, 22]
# Mean best reward: 63.15
#
#  GENERATION 2465
#
# 2465. Best individuals: [154, 112, 92, 65, 57, 48, 48, 48, 36, 36, 34, 32, 32, 32, 30, 28, 24, 24, 24, 24]
# Mean best reward: 49.0
#
#  GENERATION 2466
#
# 2466. Best individuals: [194, 164, 96, 89, 86, 78, 61, 56, 56, 56, 55, 54, 54, 52, 42, 40, 40, 38, 36, 33]
# Mean best reward: 69.0
#
#  GENERATION 2467
#
# 2467. Best individuals: [203, 90, 75, 60, 48, 47, 42, 42, 42, 42, 36, 36, 34, 32, 32, 32, 28, 24, 24, 24]
# Mean best reward: 49.65
#
#  GENERATION 2468
#
# 2468. Best individuals: [120, 105, 101, 82, 66, 64, 60, 60, 54, 51, 42, 40, 38, 36, 33, 30, 21, 20, 20, 20]
# Mean best reward: 53.15
#
#  GENERATION 2469
#
# 2469. Best individuals: [172, 116, 116, 98, 98, 84, 60, 56, 55, 50, 40, 36, 34, 32, 32, 26, 26, 24, 22, 20]
# Mean best reward: 59.85
#
#  GENERATION 2470
#
# 2470. Best individuals: [198, 102, 96, 96, 90, 84, 68, 63, 54, 44, 40, 36, 34, 32, 32, 30, 24, 24, 24, 24]
# Mean best reward: 59.75
#
#  GENERATION 2471
#
# 2471. Best individuals: [171, 156, 140, 124, 120, 84, 76, 48, 48, 46, 42, 40, 36, 36, 34, 32, 30, 24, 24, 22]
# Mean best reward: 66.65
#
#  GENERATION 2472
#
# 2472. Best individuals: [108, 96, 96, 90, 86, 84, 69, 62, 60, 48, 48, 42, 40, 40, 40, 32, 32, 30, 28, 24]
# Mean best reward: 57.75
#
#  GENERATION 2473
#
# 2473. Best individuals: [182, 134, 96, 66, 64, 48, 48, 48, 45, 44, 36, 30, 30, 28, 28, 24, 24, 24, 24, 20]
# Mean best reward: 52.15
#
#  GENERATION 2474
#
# 2474. Best individuals: [161, 144, 138, 119, 93, 81, 73, 46, 43, 40, 36, 36, 36, 30, 30, 30, 27, 24, 24, 24]
# Mean best reward: 61.75
#
#  GENERATION 2475
#
# 2475. Best individuals: [138, 117, 97, 88, 84, 77, 46, 44, 36, 36, 36, 33, 33, 32, 24, 22, 22, 18, 18, 18]
# Mean best reward: 50.95
#
#  GENERATION 2476
#
# 2476. Best individuals: [112, 108, 105, 104, 96, 56, 50, 48, 44, 34, 32, 32, 30, 28, 28, 26, 24, 24, 22, 20]
# Mean best reward: 51.15
#
#  GENERATION 2477
#
# 2477. Best individuals: [120, 88, 84, 82, 78, 76, 68, 54, 54, 48, 48, 48, 48, 36, 36, 33, 32, 28, 24, 24]
# Mean best reward: 55.45
#
#  GENERATION 2478
#
# 2478. Best individuals: [174, 110, 102, 102, 100, 86, 84, 76, 60, 56, 48, 48, 48, 46, 42, 40, 36, 34, 30, 24]
# Mean best reward: 67.3
#
#  GENERATION 2479
#
# 2479. Best individuals: [255, 162, 152, 148, 102, 84, 84, 60, 56, 54, 48, 44, 44, 24, 24, 24, 24, 24, 24, 24]
# Mean best reward: 73.05
#
#  GENERATION 2480
#
# 2480. Best individuals: [164, 132, 124, 84, 81, 64, 54, 48, 48, 40, 39, 39, 32, 26, 22, 22, 21, 20, 20, 20]
# Mean best reward: 55.0
#
#  GENERATION 2481
#
# 2481. Best individuals: [174, 76, 74, 60, 54, 54, 48, 46, 42, 42, 32, 32, 30, 30, 28, 26, 26, 24, 20, 20]
# Mean best reward: 46.9
#
#  GENERATION 2482
#
# 2482. Best individuals: [90, 82, 81, 80, 80, 80, 72, 72, 64, 54, 48, 44, 36, 30, 30, 30, 28, 24, 24, 22]
# Mean best reward: 53.55
#
#  GENERATION 2483
#
# 2483. Best individuals: [112, 99, 96, 82, 82, 78, 65, 63, 44, 42, 40, 36, 32, 32, 28, 24, 24, 24, 20, 20]
# Mean best reward: 52.15
#
#  GENERATION 2484
#
# 2484. Best individuals: [228, 135, 122, 108, 96, 78, 70, 66, 56, 56, 54, 40, 36, 36, 30, 24, 24, 24, 24, 24]
# Mean best reward: 66.55
#
#  GENERATION 2485
#
# 2485. Best individuals: [136, 122, 112, 108, 68, 66, 64, 60, 52, 44, 42, 36, 32, 30, 27, 24, 24, 24, 24, 24]
# Mean best reward: 55.95
#
#  GENERATION 2486
#
# 2486. Best individuals: [122, 96, 92, 88, 86, 72, 72, 64, 61, 50, 50, 46, 42, 42, 36, 36, 28, 26, 24, 24]
# Mean best reward: 57.85
#
#  GENERATION 2487
#
# 2487. Best individuals: [142, 111, 104, 68, 56, 54, 48, 48, 44, 42, 36, 36, 32, 32, 30, 30, 28, 24, 24, 24]
# Mean best reward: 50.65
#
#  GENERATION 2488
#
# 2488. Best individuals: [201, 160, 108, 78, 74, 72, 66, 60, 56, 50, 48, 48, 48, 40, 36, 32, 26, 24, 24, 22]
# Mean best reward: 63.65
#
#  GENERATION 2489
#
# 2489. Best individuals: [208, 129, 104, 102, 66, 60, 60, 59, 56, 54, 48, 48, 40, 40, 34, 32, 32, 32, 30, 24]
# Mean best reward: 62.9
#
#  GENERATION 2490
#
# 2490. Best individuals: [160, 129, 77, 71, 68, 68, 56, 48, 36, 34, 33, 32, 32, 28, 24, 22, 22, 18, 18, 18]
# Mean best reward: 49.7
#
#  GENERATION 2491
#
# 2491. Best individuals: [144, 130, 94, 84, 81, 80, 76, 60, 57, 56, 45, 45, 42, 32, 32, 30, 28, 28, 27, 24]
# Mean best reward: 59.75
#
#  GENERATION 2492
#
# 2492. Best individuals: [114, 91, 88, 74, 74, 73, 68, 56, 54, 52, 48, 42, 40, 36, 34, 32, 28, 26, 26, 24]
# Mean best reward: 54.0
#
#  GENERATION 2493
#
# 2493. Best individuals: [140, 125, 78, 75, 72, 64, 56, 48, 48, 48, 42, 36, 32, 32, 27, 24, 24, 20, 20, 20]
# Mean best reward: 51.55
#
#  GENERATION 2494
#
# 2494. Best individuals: [105, 66, 50, 48, 48, 46, 42, 42, 40, 36, 32, 30, 27, 24, 24, 24, 24, 22, 22, 20]
# Mean best reward: 38.6
#
#  GENERATION 2495
#
# 2495. Best individuals: [150, 139, 85, 48, 32, 30, 28, 28, 24, 24, 24, 24, 24, 24, 24, 24, 24, 22, 20, 20]
# Mean best reward: 40.9
#
#  GENERATION 2496
#
# 2496. Best individuals: [150, 132, 90, 84, 82, 82, 76, 68, 48, 48, 48, 42, 36, 32, 30, 24, 24, 24, 24, 20]
# Mean best reward: 58.2
#
#  GENERATION 2497
#
# 2497. Best individuals: [150, 124, 108, 104, 92, 90, 90, 90, 72, 66, 60, 58, 40, 36, 32, 30, 28, 24, 24, 20]
# Mean best reward: 66.9
#
#  GENERATION 2498
#
# 2498. Best individuals: [155, 96, 90, 68, 63, 56, 56, 52, 51, 50, 50, 49, 44, 36, 34, 32, 32, 30, 28, 24]
# Mean best reward: 54.8
#
#  GENERATION 2499
#
# 2499. Best individuals: [72, 72, 72, 64, 57, 56, 48, 42, 36, 32, 32, 32, 30, 30, 28, 28, 27, 27, 24, 24]
# Mean best reward: 41.65
#
#  GENERATION 2500
#
# 2500. Best individuals: [116, 112, 90, 72, 60, 54, 54, 48, 46, 32, 28, 28, 28, 26, 24, 24, 24, 20, 20, 20]
# Mean best reward: 46.3
#
#  GENERATION 2501
#
# 2501. Best individuals: [136, 114, 102, 96, 60, 42, 40, 36, 36, 28, 24, 24, 24, 24, 24, 24, 24, 20, 20, 20]
# Mean best reward: 45.9
#
#  GENERATION 2502
#
# 2502. Best individuals: [142, 121, 116, 99, 76, 60, 56, 56, 47, 45, 40, 36, 36, 36, 36, 27, 24, 24, 24, 24]
# Mean best reward: 56.25
#
#  GENERATION 2503
# InterruptException:
#
# Stacktrace:
#  [1] Weights
#    @ ~/.julia/packages/StatsBase/ebrT3/src/weights.jl:17 [inlined]
#  [2] Weights
#    @ ~/.julia/packages/StatsBase/ebrT3/src/weights.jl:20 [inlined]
#  [3] Weights(values::Vector{Float32})
#    @ StatsBase ~/.julia/packages/StatsBase/ebrT3/src/weights.jl:21
#  [4] add_point(input_state::Vector{Int64}, action_vec::Vector{Float32}, n::Int64)
#    @ Main ./In[9]:7
#  [5] generate_session(agent::Chain{Tuple{Dense{typeof(relu), Matrix{Float32}, Vector{Float32}}, Dense{typeof(relu), Matrix{Float32}, Vector{Float32}}, Dense{typeof(relu), Matrix{Float32}, Vector{Float32}}, Dense{typeof(σ), Matrix{Float32}, Vector{Float32}}}}, corner_agent::Chain{Tuple{Dense{typeof(relu), Matrix{Float32}, Vector{Float32}}, Dense{typeof(relu), Matrix{Float32}, Vector{Float32}}, Dense{typeof(relu), Matrix{Float32}, Vector{Float32}}, Dense{typeof(σ), Matrix{Float32}, Vector{Float32}}}}, n_sessions::Int64, n::Int64)
#    @ Main ./In[10]:153
#  [6] train(board_size::Int64, filename::String)
#    @ Main ./In[31]:46
